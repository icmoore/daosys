# %% [markdown]
# ### Simulation: Masternode Yield Farming

# %%
import os
import copy
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from IPython.display import Image
cwd =  os.getcwd().replace("notebooks/simulation","")
os.chdir(cwd)

from python.dev.helper import Helper

from python.dev.simulation import SimulationOrchestrator
from python.dev.simulation import EventQueue
from python.dev.simulation import EventExecutor
from python.dev.simulation.batch import ActionBatch
from python.dev.simulation.batch import MergeBatch

from python.dev.agent import TokenAgent
from python.dev.agent import LPTokenAgent
from python.dev.agent import UserAgent

from python.dev.action import MintAction
from python.dev.action import DepositAction
from python.dev.action import LPDepositChainAction
from python.dev.action import DepositChainAction
from python.dev.action import WithdrawChainAction
from python.dev.action import WithdrawAction
from python.dev.action import SwapAction
from python.dev.event import Mint
from python.dev.event import Deposit
from python.dev.event import Withdraw
from python.dev.event import Swap

from python.dev.math.model import TokenDeltaModel
from python.dev.math.model import TimeDeltaModel
from python.dev.math.model import ModelQueue

from python.dev.lp import LiquidityPool
from python.dev.lp.event import LPEvent
from python.dev.lp.event import MintLPEvent
from python.dev.lp.event import DepositLPEvent
from python.dev.lp.event import SwapLPEvent

# %%
Image("images/jupyter/tutorials/masternode_nft.png", width = 600, height = 600)

# %% [markdown]
# ### Load Data

# %%
daosys_proj = pd.read_csv('notebooks/resources/daosys_proj.csv')

# %% [markdown]
# ### Initialize Agents

# %%
USER1 = UserAgent('USER1')
USER2 = UserAgent('USER2')

SYS = TokenAgent('SYS')
DAI = TokenAgent('DAI')

SYS_DAI_LP = LiquidityPool('SYS/DAI', USER1, SYS, DAI)
SYS_DAI = LPTokenAgent('SYS_DAI_LP', SYS_DAI_LP)

# %% [markdown]
# ### Mint Tokens

# %%
apy = 0.1
t_delta = 109*24*3600

# %%
SYS_mint1 = Mint(5000, apy, True)
DAI_mint1 = Mint(5000, apy, True)
SYS_DAI_LP_mint1 = Mint(0, apy, True)

SYS_mint2 = Mint(100000, apy, True)
DAI_mint2 = Mint(0, apy, True)
SYS_mint3 = Mint(1000, apy, True)
SYS_DAI_LP_mint2 = Mint(0, apy, True)

# %%
m_action1 = MintAction(SYS_mint1, SYS, USER1)
m_action2 = MintAction(DAI_mint1, DAI, USER1)
m_action3 = MintAction(SYS_DAI_LP_mint1, SYS_DAI, USER1)

m_action4 = MintAction(SYS_mint2, SYS, USER2)
m_action5 = MintAction(DAI_mint2, DAI, USER2)
m_action6 = MintAction(SYS_DAI_LP_mint2, SYS_DAI, USER2)
m_action7 = MintAction(SYS_mint3, SYS, USER1)

# %% [markdown]
# ### Setup Actions

# %%
sub_withdraw1 = Withdraw(apy, 2500, 0) 
sub_withdraw2 = Withdraw(apy, 2500, 0) 
w_action1 = WithdrawAction(sub_withdraw1, SYS, USER1, SYS_mint1.get_id())
w_action2 = WithdrawAction(sub_withdraw2, DAI, USER1, DAI_mint1.get_id())
d_action1 = LPDepositChainAction(w_action1, w_action2, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 1

# %%
deposit_obj1 = ModelQueue().apply(daosys_proj['mn_nsys'].values, 200)
withdraw_obj2 = ModelQueue().apply(daosys_proj['mn_nsys'].values/2, 200)
t_delta_obj1 = ModelQueue().apply(TimeDeltaModel().apply(p = 0.0001, n = 200))
t_delta_obj2 = copy.copy(t_delta_obj1)
t_delta = 3600*24

# %%
deposit1 = Deposit(apy, deposit_obj1, t_delta) 
sub_withdraw1 = Withdraw(apy, 2500, 0)
sub_deposit1 = Deposit(apy, withdraw_obj2, t_delta)
withdraw1 = Withdraw(apy, 2500, 0)

# %%
# Deposit 5000 SYS
d_action2 = DepositAction(deposit1, SYS, USER2, SYS_mint2.get_id())

# Swap 2500 SYS for DAI
sub_w_action1 = WithdrawAction(sub_withdraw1, SYS, USER2, SYS_mint2.get_id())
sub_d_action1 = DepositAction(sub_deposit1, DAI, USER2, DAI_mint2.get_id())
s_action1 = SwapAction(sub_w_action1, sub_d_action1)

# Withdraw DAI proceeds and 2500 SYS
w_action3 = WithdrawChainAction(s_action1, DAI, USER2, DAI_mint2.get_id())
w_action4 = WithdrawAction(withdraw1, SYS, USER2, SYS_mint2.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action3 = LPDepositChainAction(w_action3, w_action4, SYS_DAI, USER1, SYS_DAI_LP_mint2.get_id())

# %% [markdown]
# ### Batchset 2

# %%
deposit2 = Deposit(apy, 50, t_delta_obj1) 
sub_withdraw2 = Withdraw(apy, 25, 0)
sub_deposit2 = Deposit(apy, 25, t_delta_obj2)
withdraw2 = Withdraw(apy, 25, 0)

# %%
# Deposit 50 SYS
d_action4 = DepositAction(deposit2, SYS, USER1, SYS_mint1.get_id())

# Swap 2500 SYS for DAI
sub_w_action2 = WithdrawAction(sub_withdraw2, SYS, USER1, SYS_mint1.get_id())
sub_d_action2 = DepositAction(sub_deposit2, DAI, USER1, DAI_mint1.get_id())
s_action2 = SwapAction(sub_w_action2, sub_d_action2)

# Withdraw DAI proceeds and 2500 SYS
w_action5 = WithdrawChainAction(s_action2, DAI, USER1, DAI_mint1.get_id())
w_action6 = WithdrawAction(withdraw2, SYS, USER1, SYS_mint1.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action5 = LPDepositChainAction(w_action5, w_action6, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 3

# %%
r_deposit_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))
r_withdraw_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))

deposit1a = Deposit(apy, r_deposit_obj, t_delta/1.3) 
withdraw1a = Withdraw(apy, r_withdraw_obj, 0) 

d_action1a = DepositAction(deposit1a, SYS, USER1, SYS_mint3.get_id())
w_action1a = WithdrawAction(withdraw1a, SYS, USER1, SYS_mint3.get_id())

# %%
aBatch2 = ActionBatch('RUN2', 100)
aBatch2.add_action(d_action1a)
aBatch2.add_action(w_action1a)
aBatch2.reset_actions(d_action1a, w_action1a)
aBatch2.inspect()
# Out:
#  ** BATCH **
# USER1 DEPOSITs SYS
# USER1 WITHDRAWs SYS
#
#  ** REPEAT BATCH **
#  100 times
#
#  ** RUNTIME for 1st BATCH **
# 66461.53846153845 seconds

# %% [markdown]
# ### Setup Batch 1

# %%
sBatch1 = ActionBatch('SETUP1')
sBatch1.init_action(m_action1)
sBatch1.init_action(m_action2)
sBatch1.init_action(m_action3)
sBatch1.init_action(w_action1)
sBatch1.init_action(w_action2)
sBatch1.init_action(d_action1)
sBatch1.inspect()
# Out:
# ** SETUP **
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# USER1 WITHDRAWs SYS
# USER1 WITHDRAWs DAI
# USER1 DEPOSITs SYS and DAI proceeds into SYS_DAI_LP

# %%
sBatch2 = ActionBatch('SETUP2')
sBatch2.init_action(m_action4)
sBatch2.init_action(m_action5)
sBatch2.init_action(m_action6)
sBatch2.init_action(m_action7)
sBatch2.inspect()
# Out:
# ** SETUP **
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS

# %%
aBatch1 = ActionBatch('RUN1', 200)
aBatch1.add_action(d_action2)
aBatch1.add_action(s_action1)
aBatch1.add_action(w_action3)
aBatch1.add_action(w_action4)
aBatch1.add_action(d_action3)
aBatch1.reset_actions(d_action2, w_action4)
aBatch1.inspect()
# Out:
#  ** BATCH **
# USER2 DEPOSITs SYS
# USER2 SWAPs SYS for DAI
# USER2 WITHDRAWs DAI proceeds
# USER2 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 86400 seconds

# %%
# Python3 program for the above approach
from queue import PriorityQueue
 
# Function to merge two arrays
def merge(A, B, N, M, AName = 'A', BName = 'B'):
 
    # Stores the merged array
    res = [0 for i in range(N + M)]
     
    # Create a min priority_queue
    pq = PriorityQueue()
     
    # Traverse the array A[]
    for i in range(N):
        pq.put([A[i], AName, i])
         
    # Traverse the array B[]
    for i in range(M):
        pq.put([B[i], BName, i])
 
    j = 0
     
    # Iterate until the
    # pq is not empty
    while not pq.empty():
       
        # Removes the top element and
        # stores it into res[j]
        res[j] = pq.get()
        j += 1
         
    # Print the merged array
    #for i in range(N + M):
    #    print(res[i], end = " ")
        
    # return back to main
    return  np.array(res)  

def get_time(batch):

    t_deltas = np.array([])
    for item in batch['action']: 
        val = batch['action'][item]['t_delta']
        if(len(t_deltas) != 0):
            val=val+t_deltas[-1] 
        t_deltas = np.append(t_deltas, val) 
        
    return t_deltas

# %%
batch1 = sBatch1.generate()
batch2 = sBatch2.generate()
batch3 = aBatch1.generate()
batch4 = aBatch2.generate()

# %%
mb = MergeBatch('RUN1RUN2')
mb.add(batch3)
mb.add(batch4)
batch_merge = mb.merge()

# %%
q2 = EventQueue()
q2.add_event_batch(batch1)
q2.add_event_batch(batch2)
q2.add_event_batch(batch_merge)
#q2.add_event_batch(batch4)
#q2.add_event_batch(batch3)
#q2.add_event_batch(batch4)

# %% [markdown]
# ### Execute events

# %%
orchestrator = SimulationOrchestrator(verbose = True)
executor = EventExecutor(q2, orchestrator)
executor.run()
# Out:
# ======== Action Tasks ===========
# # num_tasks: 1210
#
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# [2022-08-16 18:05:17] USER1 WITHDRAWs 2500.00 SYS
# [2022-08-16 18:05:17] USER1 WITHDRAWs 2500.00 DAI
# [2022-08-16 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS
# [2022-08-17 12:32:58] USER1 DEPOSITs 5015.57 SYS
# [2022-08-17 12:32:58] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-17 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-17 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-17 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-17 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-17 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-18 07:00:40] USER1 DEPOSITs 5015.57 SYS
# [2022-08-18 07:00:40] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-18 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-18 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-18 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-18 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-18 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-19 01:28:22] USER1 DEPOSITs 5015.57 SYS
# [2022-08-19 01:28:22] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-19 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-19 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-19 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-19 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-19 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-19 19:56:03] USER1 DEPOSITs 5015.57 SYS
# [2022-08-19 19:56:03] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-20 14:23:45] USER1 DEPOSITs 5015.57 SYS
# [2022-08-20 14:23:45] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-20 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-20 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-20 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-20 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-20 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-21 08:51:26] USER1 DEPOSITs 5015.57 SYS
# [2022-08-21 08:51:26] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-21 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-21 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-21 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-21 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-21 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-22 03:19:08] USER1 DEPOSITs 5015.57 SYS
# [2022-08-22 03:19:08] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-22 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-22 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-22 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-22 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-22 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-22 21:46:49] USER1 DEPOSITs 5015.57 SYS
# [2022-08-22 21:46:49] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-23 16:14:31] USER1 DEPOSITs 5015.57 SYS
# [2022-08-23 16:14:31] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-23 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-23 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-23 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-23 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-23 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-24 10:42:12] USER1 DEPOSITs 5015.57 SYS
# [2022-08-24 10:42:12] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-24 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-24 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-24 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-24 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-24 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-25 05:09:54] USER1 DEPOSITs 5015.57 SYS
# [2022-08-25 05:09:54] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-25 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-25 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-25 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-25 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-25 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-25 23:37:35] USER1 DEPOSITs 5015.57 SYS
# [2022-08-25 23:37:35] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-26 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-26 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-26 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-26 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-26 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-26 18:05:17] USER1 DEPOSITs 5015.57 SYS
# [2022-08-26 18:05:17] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-27 12:32:58] USER1 DEPOSITs 5015.57 SYS
# [2022-08-27 12:32:58] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-27 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-27 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-27 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-27 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-27 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-28 07:00:40] USER1 DEPOSITs 5015.57 SYS
# [2022-08-28 07:00:40] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-28 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-28 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-28 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-28 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-28 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-29 01:28:22] USER1 DEPOSITs 5015.57 SYS
# [2022-08-29 01:28:22] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-29 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-29 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-29 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-29 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-29 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-29 19:56:03] USER1 DEPOSITs 5015.57 SYS
# [2022-08-29 19:56:03] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-30 14:23:45] USER1 DEPOSITs 5015.57 SYS
# [2022-08-30 14:23:45] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-30 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-30 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-30 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-30 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-30 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-08-31 08:51:26] USER1 DEPOSITs 5015.57 SYS
# [2022-08-31 08:51:26] USER1 WITHDRAWs 5019.76 SYS
# [2022-08-31 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-08-31 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-08-31 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-08-31 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-31 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-01 03:19:08] USER1 DEPOSITs 5015.57 SYS
# [2022-09-01 03:19:08] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-01 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-01 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-01 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-01 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-01 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-01 21:46:49] USER1 DEPOSITs 5015.57 SYS
# [2022-09-01 21:46:49] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-02 16:14:31] USER1 DEPOSITs 5015.57 SYS
# [2022-09-02 16:14:31] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-02 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-02 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-02 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-02 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-02 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-03 10:42:12] USER1 DEPOSITs 5015.57 SYS
# [2022-09-03 10:42:12] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-03 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-03 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-03 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-03 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-03 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-04 05:09:54] USER1 DEPOSITs 5015.57 SYS
# [2022-09-04 05:09:54] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-04 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-04 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-04 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-04 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-04 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-04 23:37:35] USER1 DEPOSITs 5015.57 SYS
# [2022-09-04 23:37:35] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-05 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-05 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-05 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-05 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-05 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-05 18:05:17] USER1 DEPOSITs 5015.57 SYS
# [2022-09-05 18:05:17] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-06 12:32:58] USER1 DEPOSITs 5015.57 SYS
# [2022-09-06 12:32:58] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-06 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-06 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-06 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-06 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-06 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-07 07:00:40] USER1 DEPOSITs 5015.57 SYS
# [2022-09-07 07:00:40] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-07 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-07 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-07 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-07 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-07 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-08 01:28:22] USER1 DEPOSITs 5015.57 SYS
# [2022-09-08 01:28:22] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-08 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-08 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-08 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-08 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-08 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-08 19:56:03] USER1 DEPOSITs 5015.57 SYS
# [2022-09-08 19:56:03] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-09 14:23:45] USER1 DEPOSITs 5015.57 SYS
# [2022-09-09 14:23:45] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-09 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-09 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-09 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-09 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-09 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-10 08:51:26] USER1 DEPOSITs 5015.57 SYS
# [2022-09-10 08:51:26] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-10 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-10 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-10 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-10 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-10 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-11 03:19:08] USER1 DEPOSITs 5015.57 SYS
# [2022-09-11 03:19:08] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-11 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-11 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-11 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-11 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-11 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-11 21:46:49] USER1 DEPOSITs 5015.57 SYS
# [2022-09-11 21:46:49] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-12 16:14:31] USER1 DEPOSITs 5015.57 SYS
# [2022-09-12 16:14:31] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-12 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-12 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-12 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-12 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-12 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-13 10:42:12] USER1 DEPOSITs 5015.57 SYS
# [2022-09-13 10:42:12] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-13 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-13 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-13 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-13 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-13 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-14 05:09:54] USER1 DEPOSITs 5015.57 SYS
# [2022-09-14 05:09:54] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-14 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-14 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-14 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-14 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-14 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-14 23:37:35] USER1 DEPOSITs 5015.57 SYS
# [2022-09-14 23:37:35] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-15 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-15 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-15 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-15 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-15 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-15 18:05:17] USER1 DEPOSITs 5015.57 SYS
# [2022-09-15 18:05:17] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-16 12:32:58] USER1 DEPOSITs 5015.57 SYS
# [2022-09-16 12:32:58] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-16 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-16 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-16 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-16 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-16 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-17 07:00:40] USER1 DEPOSITs 5015.57 SYS
# [2022-09-17 07:00:40] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-17 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-17 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-17 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-17 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-17 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-18 01:28:22] USER1 DEPOSITs 5015.57 SYS
# [2022-09-18 01:28:22] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-18 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-18 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-18 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-18 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-18 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-18 19:56:03] USER1 DEPOSITs 5015.57 SYS
# [2022-09-18 19:56:03] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-19 14:23:45] USER1 DEPOSITs 5015.57 SYS
# [2022-09-19 14:23:45] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-19 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-19 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-19 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-19 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-19 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-20 08:51:26] USER1 DEPOSITs 5015.57 SYS
# [2022-09-20 08:51:26] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-20 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-20 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-20 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-20 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-20 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-21 03:19:08] USER1 DEPOSITs 5015.57 SYS
# [2022-09-21 03:19:08] USER1 WITHDRAWs 5019.76 SYS
# [2022-09-21 18:05:17] USER2 DEPOSITs 5000.00 SYS
# [2022-09-21 18:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2022-09-21 18:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2022-09-21 18:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-21 18:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2022-09-21 21:46:49] USER1 DEPOSITs 5015.57 SYS
# [2022
17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-15 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-15 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-15 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-15 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-15 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-16 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-16 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-16 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-16 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-16 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-17 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-17 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-17 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-17 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-17 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-18 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-18 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-18 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-18 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-18 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-19 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-19 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-19 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-19 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-19 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-20 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-20 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-20 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-20 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-20 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-21 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-21 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-21 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-21 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-21 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-22 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-22 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-22 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-22 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-22 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-23 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-23 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-23 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-23 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-23 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-24 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-24 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-24 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-24 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-24 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-25 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-25 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-25 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-25 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-25 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-26 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-26 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-26 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-26 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-26 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-27 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-27 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-27 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-27 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-27 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-28 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-28 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-28 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-28 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-28 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-29 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-29 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-29 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-29 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-29 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-30 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-30 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-30 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-30 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-30 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-01-31 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-01-31 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-01-31 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-01-31 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-01-31 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-01 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-01 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-01 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-01 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-01 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-02 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-02 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-02 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-02 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-02 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-03 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-03 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-03 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-03 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-03 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-04 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-04 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-04 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-04 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-04 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-05 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-05 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-05 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-05 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-05 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-06 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-06 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-06 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-06 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-06 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-07 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-07 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-07 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-07 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-07 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-08 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-08 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-08 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-08 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-08 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-09 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-09 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-09 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-09 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-09 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-10 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-10 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-10 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-10 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-10 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-11 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-11 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-11 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-11 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-11 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-12 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-12 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-12 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-12 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-12 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-13 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-13 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-13 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-13 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-13 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-14 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-14 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-14 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-14 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-14 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-15 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-15 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-15 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-15 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-15 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-16 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-16 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-16 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-16 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-16 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-17 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-17 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-17 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-17 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-17 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-18 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-18 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-18 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-18 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-18 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-19 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-19 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-19 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-19 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-19 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-20 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-20 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-20 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-20 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-20 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-21 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-21 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-21 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-21 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-21 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-22 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-22 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-22 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-22 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-22 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-23 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-23 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-23 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-23 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-23 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-24 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-24 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-24 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-24 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-24 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-25 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-25 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-25 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-25 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-25 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-26 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-26 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-26 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-26 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-26 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-27 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-27 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-27 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-27 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-27 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-02-28 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-02-28 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-02-28 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-02-28 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-28 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-03-01 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-03-01 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-03-01 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-03-01 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-01 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-03-02 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-03-02 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-03-02 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-03-02 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-02 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-03-03 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-03-03 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-03-03 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-03-03 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-03 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# [2023-03-04 17:05:17] USER2 DEPOSITs 5000.00 SYS
# [2023-03-04 17:05:17] USER2 SWAPs 2500.00 SYS for DAI
# [2023-03-04 17:05:17] USER2 WITHDRAWs 2500.00 from DAI proceeds
# [2023-03-04 17:05:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-04 17:05:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds

# %% [markdown]
# ### Analyze

# %%
tSYS = SYS.get_token()
tDAI = DAI.get_token()
tSYS_DAI = SYS_DAI.get_token()

SYS_addr1 = SYS.get_address(SYS_mint1.get_id())
DAI_addr1 = DAI.get_address(DAI_mint1.get_id())
SYS_DAI_addr1 = SYS_DAI.get_address(SYS_DAI_LP_mint1.get_id())

# %%
SYS_states1 = tSYS.get_state_series(SYS_addr1)
principle = SYS_states1.get_principle() 
balance = SYS_states1.get_balance() 
tSamp = SYS_states1.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_ax.set_title("USER1: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states1 = tDAI.get_state_series(DAI_addr1)
principle = DAI_states1.get_principle() 
balance = DAI_states1.get_balance() 
tSamp = DAI_states1.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER1: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states1 = tSYS_DAI.get_state_series(SYS_DAI_addr1)
principle = SYS_DAI_states1.get_principle() 
balance = SYS_DAI_states1.get_balance() 
tSamp = SYS_DAI_states1.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
SYS_addr2 = SYS.get_address(SYS_mint2.get_id())
DAI_addr2 = DAI.get_address(DAI_mint2.get_id())
SYS_DAI_addr2 = SYS_DAI.get_address(SYS_DAI_LP_mint2.get_id())

# %%
SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp()

# %%
# Analyze Token balances

SYS_states2 = tSYS.get_state_series(SYS_addr2)
principle = SYS_states2.get_principle() 
balance = SYS_states2.get_balance() 
tSamp = SYS_states2.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp, balance, label='balance') 
SYS_ax.plot(tSamp, principle, label='principle') 
SYS_ax.set_title("USER2: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states2 = tDAI.get_state_series(DAI_addr2)
principle = DAI_states2.get_principle() 
balance = DAI_states2.get_balance() 
tSamp = DAI_states2.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER2: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
tSamp = SYS_DAI_LP.get_lp_events().get_dates()
utSamp = SYS_DAI_LP.get_lp_events().get_unix_time_stamps()
prices = SYS_DAI_LP.get_lp_events().get_prices()
liquidities = SYS_DAI_LP.get_lp_events().get_liquidity_values()
balances = SYS_DAI_LP.get_lp_events().gen_yield_balances(apy)

fig, (liq_ax) = plt.subplots(nrows=1, sharex=True, sharey=False, figsize=(18, 15))

liq_ax.plot(tSamp, liquidities, label='liquidities') 
liq_ax.plot(tSamp, balances, label='liquidities') 
liq_ax.set_title("Total SYS_DAI_LP Balance (rebasing token)", fontsize=20)
liq_ax.set_ylabel("Token balance", fontsize=16)
liq_ax.set_xlabel('Time', fontsize=16)
liq_ax.legend()
