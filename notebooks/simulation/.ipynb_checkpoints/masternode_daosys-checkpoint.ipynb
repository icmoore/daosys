# %% [markdown]
# ### Simulation: Masternode Yield Farming

# %%
import os
import copy
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from IPython.display import Image
cwd =  os.getcwd().replace("notebooks/simulation","")
os.chdir(cwd)

from python.dev.helper import Helper

from python.dev.simulation import SimulationOrchestrator
from python.dev.simulation import EventQueue
from python.dev.simulation import EventExecutor
from python.dev.simulation.batch import ActionBatch

from python.dev.agent import TokenAgent
from python.dev.agent import LPTokenAgent
from python.dev.agent import UserAgent

from python.dev.action import MintAction
from python.dev.action import DepositAction
from python.dev.action import LPDepositChainAction
from python.dev.action import DepositChainAction
from python.dev.action import WithdrawChainAction
from python.dev.action import WithdrawAction
from python.dev.action import SwapAction
from python.dev.event import Mint
from python.dev.event import Deposit
from python.dev.event import Withdraw
from python.dev.event import Swap

from python.dev.math.model import TokenDeltaModel
from python.dev.math.model import TimeDeltaModel
from python.dev.math.model import ModelQueue

from python.dev.lp import LiquidityPool
from python.dev.lp.event import LPEvent
from python.dev.lp.event import MintLPEvent
from python.dev.lp.event import DepositLPEvent
from python.dev.lp.event import SwapLPEvent

# %%
Image("images/jupyter/tutorials/masternode_nft.png", width = 600, height = 600)

# %% [markdown]
# ### Load Data

# %%
daosys_proj = pd.read_csv('notebooks/resources/daosys_proj.csv')

# %% [markdown]
# ### Initialize Agents

# %%
USER1 = UserAgent('USER1')
USER2 = UserAgent('USER2')

SYS = TokenAgent('SYS')
DAI = TokenAgent('DAI')

SYS_DAI_LP = LiquidityPool('SYS/DAI', USER1, SYS, DAI)
SYS_DAI = LPTokenAgent('SYS_DAI_LP', SYS_DAI_LP)

# %% [markdown]
# ### Mint Tokens

# %%
apy = 0.1
t_delta = 109*24*3600

# %%
SYS_mint1 = Mint(5000, apy, True)
DAI_mint1 = Mint(5000, apy, True)
SYS_DAI_LP_mint1 = Mint(0, apy, True)

SYS_mint2 = Mint(100000, apy, True)
DAI_mint2 = Mint(0, apy, True)
SYS_DAI_LP_mint2 = Mint(0, apy, True)

# %%
m_action1 = MintAction(SYS_mint1, SYS, USER1)
m_action2 = MintAction(DAI_mint1, DAI, USER1)
m_action3 = MintAction(SYS_DAI_LP_mint1, SYS_DAI, USER1)

m_action4 = MintAction(SYS_mint2, SYS, USER2)
m_action5 = MintAction(DAI_mint2, DAI, USER2)
m_action6 = MintAction(SYS_DAI_LP_mint2, SYS_DAI, USER2)

# %% [markdown]
# ### Setup Actions

# %%
sub_withdraw1 = Withdraw(apy, 2500, 0) 
sub_withdraw2 = Withdraw(apy, 2500, 0) 
w_action1 = WithdrawAction(sub_withdraw1, SYS, USER1, SYS_mint1.get_id())
w_action2 = WithdrawAction(sub_withdraw2, DAI, USER1, DAI_mint1.get_id())
d_action1 = LPDepositChainAction(w_action1, w_action2, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 1

# %%
deposit_obj1 = ModelQueue().apply(daosys_proj['mn_nsys'].values, 200)
withdraw_obj2 = ModelQueue().apply(daosys_proj['mn_nsys'].values/2, 200)
t_delta_obj1 = ModelQueue().apply(TimeDeltaModel().apply(p = 0.0001, n = 200))
t_delta_obj2 = copy.copy(t_delta_obj1)
t_delta = 3600*24

# %%
deposit1 = Deposit(apy, 5000, t_delta) 
sub_withdraw1 = Withdraw(apy, 2500, 0)
sub_deposit1 = Deposit(apy, 2500, t_delta)
withdraw1 = Withdraw(apy, 2500, 0)

# %%
# Deposit 5000 SYS
d_action2 = DepositAction(deposit1, SYS, USER2, SYS_mint2.get_id())

# Swap 2500 SYS for DAI
sub_w_action1 = WithdrawAction(sub_withdraw1, SYS, USER2, SYS_mint2.get_id())
sub_d_action1 = DepositAction(sub_deposit1, DAI, USER2, DAI_mint2.get_id())
s_action1 = SwapAction(sub_w_action1, sub_d_action1)

# Withdraw DAI proceeds and 2500 SYS
w_action3 = WithdrawChainAction(s_action1, DAI, USER2, DAI_mint2.get_id())
w_action4 = WithdrawAction(withdraw1, SYS, USER2, SYS_mint2.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action3 = LPDepositChainAction(w_action3, w_action4, SYS_DAI, USER1, SYS_DAI_LP_mint2.get_id())

# %% [markdown]
# ### Batchset 2

# %%
deposit2 = Deposit(apy, 50, t_delta_obj1) 
sub_withdraw2 = Withdraw(apy, 25, 0)
sub_deposit2 = Deposit(apy, 25, t_delta_obj2)
withdraw2 = Withdraw(apy, 25, 0)

# %%
# Deposit 50 SYS
d_action4 = DepositAction(deposit2, SYS, USER1, SYS_mint1.get_id())

# Swap 2500 SYS for DAI
sub_w_action2 = WithdrawAction(sub_withdraw2, SYS, USER1, SYS_mint1.get_id())
sub_d_action2 = DepositAction(sub_deposit2, DAI, USER1, DAI_mint1.get_id())
s_action2 = SwapAction(sub_w_action2, sub_d_action2)

# Withdraw DAI proceeds and 2500 SYS
w_action5 = WithdrawChainAction(s_action2, DAI, USER1, DAI_mint1.get_id())
w_action6 = WithdrawAction(withdraw2, SYS, USER1, SYS_mint1.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action5 = LPDepositChainAction(w_action5, w_action6, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 3

# %%
r_deposit_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))
r_withdraw_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))

deposit1a = Deposit(apy, r_deposit_obj, t_delta) 
withdraw1a = Withdraw(apy, r_withdraw_obj, 0) 

d_action1a = DepositAction(deposit1a, SYS, USER2, SYS_mint2.get_id())
w_action1a = WithdrawAction(withdraw1a, SYS, USER2, SYS_mint2.get_id())

# %%
aBatch2 = ActionBatch('RUN2', 200)
aBatch2.add_action(d_action1a)
aBatch2.add_action(w_action1a)
aBatch2.reset_actions(d_action1a, w_action1a)
aBatch2.inspect()
# Out:
#  ** BATCH **
# USER2 DEPOSITs SYS
# USER2 WITHDRAWs SYS
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 86400 seconds

# %% [markdown]
# ### Setup Batch 1

# %%
sBatch1 = ActionBatch('SETUP1')
sBatch1.init_action(m_action1)
sBatch1.init_action(m_action2)
sBatch1.init_action(m_action3)
sBatch1.init_action(w_action1)
sBatch1.init_action(w_action2)
sBatch1.init_action(d_action1)
sBatch1.inspect()
# Out:
# ** SETUP **
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# USER1 WITHDRAWs SYS
# USER1 WITHDRAWs DAI
# USER1 DEPOSITs SYS and DAI proceeds into SYS_DAI_LP

# %%
sBatch2 = ActionBatch('SETUP2')
sBatch2.init_action(m_action4)
sBatch2.init_action(m_action5)
sBatch2.init_action(m_action6)
sBatch2.inspect()
# Out:
# ** SETUP **
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP

# %%
aBatch1 = ActionBatch('RUN1', 200)
aBatch1.add_action(d_action2)
aBatch1.add_action(s_action1)
aBatch1.add_action(w_action3)
aBatch1.add_action(w_action4)
aBatch1.add_action(d_action3)
aBatch1.reset_actions(d_action2, w_action4)
aBatch1.inspect()
# Out:
#  ** BATCH **
# USER2 DEPOSITs SYS
# USER2 SWAPs SYS for DAI
# USER2 WITHDRAWs DAI proceeds
# USER2 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 86400 seconds

# %%
#batch4
# Out:
# {'name': 'RUN2',
#  'n_batches': 200,
#  'init': [],
#  'action': {0: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692385730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6923857f0>],
#    't_delta': 86400},
#   1: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6923858b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692385970>],
#    't_delta': 86400},
#   2: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692385a30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692385af0>],
#    't_delta': 86400},
#   3: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692385bb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692385c70>],
#    't_delta': 86400},
#   4: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692385d30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692385df0>],
#    't_delta': 86400},
#   5: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692385eb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692385f70>],
#    't_delta': 86400},
#   6: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387130>],
#    't_delta': 86400},
#   7: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6923871f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6923872b0>],
#    't_delta': 86400},
#   8: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387430>],
#    't_delta': 86400},
#   9: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6923874f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6923875b0>],
#    't_delta': 86400},
#   10: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387730>],
#    't_delta': 86400},
#   11: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6923877f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6923878b0>],
#    't_delta': 86400},
#   12: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387a30>],
#    't_delta': 86400},
#   13: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387bb0>],
#    't_delta': 86400},
#   14: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387d30>],
#    't_delta': 86400},
#   15: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692387eb0>],
#    't_delta': 86400},
#   16: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692387f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a070>],
#    't_delta': 86400},
#   17: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a1f0>],
#    't_delta': 86400},
#   18: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a2b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a370>],
#    't_delta': 86400},
#   19: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a4f0>],
#    't_delta': 86400},
#   20: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a5b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a670>],
#    't_delta': 86400},
#   21: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a7f0>],
#    't_delta': 86400},
#   22: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238a8b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238a970>],
#    't_delta': 86400},
#   23: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238aa30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238aaf0>],
#    't_delta': 86400},
#   24: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238abb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238ac70>],
#    't_delta': 86400},
#   25: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238ad30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238adf0>],
#    't_delta': 86400},
#   26: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238aeb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238af70>],
#    't_delta': 86400},
#   27: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c130>],
#    't_delta': 86400},
#   28: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c1f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c2b0>],
#    't_delta': 86400},
#   29: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c430>],
#    't_delta': 86400},
#   30: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c4f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c5b0>],
#    't_delta': 86400},
#   31: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c730>],
#    't_delta': 86400},
#   32: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c7f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238c8b0>],
#    't_delta': 86400},
#   33: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238c970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238ca30>],
#    't_delta': 86400},
#   34: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238caf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238cbb0>],
#    't_delta': 86400},
#   35: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238cc70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238cd30>],
#    't_delta': 86400},
#   36: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238cdf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238ceb0>],
#    't_delta': 86400},
#   37: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238cf70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e070>],
#    't_delta': 86400},
#   38: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e1f0>],
#    't_delta': 86400},
#   39: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e2b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e370>],
#    't_delta': 86400},
#   40: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e4f0>],
#    't_delta': 86400},
#   41: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e5b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e670>],
#    't_delta': 86400},
#   42: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e7f0>],
#    't_delta': 86400},
#   43: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238e8b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238e970>],
#    't_delta': 86400},
#   44: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238ea30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238eaf0>],
#    't_delta': 86400},
#   45: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238ebb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238ec70>],
#    't_delta': 86400},
#   46: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238ed30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238edf0>],
#    't_delta': 86400},
#   47: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69238eeb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69238ef70>],
#    't_delta': 86400},
#   48: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449130>],
#    't_delta': 86400},
#   49: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924491f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924492b0>],
#    't_delta': 86400},
#   50: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449430>],
#    't_delta': 86400},
#   51: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924494f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924495b0>],
#    't_delta': 86400},
#   52: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449730>],
#    't_delta': 86400},
#   53: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924497f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924498b0>],
#    't_delta': 86400},
#   54: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449a30>],
#    't_delta': 86400},
#   55: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449bb0>],
#    't_delta': 86400},
#   56: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449d30>],
#    't_delta': 86400},
#   57: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692449eb0>],
#    't_delta': 86400},
#   58: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692449f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b070>],
#    't_delta': 86400},
#   59: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b1f0>],
#    't_delta': 86400},
#   60: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b2b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b370>],
#    't_delta': 86400},
#   61: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b4f0>],
#    't_delta': 86400},
#   62: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b5b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b670>],
#    't_delta': 86400},
#   63: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b7f0>],
#    't_delta': 86400},
#   64: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244b8b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244b970>],
#    't_delta': 86400},
#   65: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244ba30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244baf0>],
#    't_delta': 86400},
#   66: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244bbb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244bc70>],
#    't_delta': 86400},
#   67: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244bd30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244bdf0>],
#    't_delta': 86400},
#   68: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244beb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244bf70>],
#    't_delta': 86400},
#   69: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e130>],
#    't_delta': 86400},
#   70: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e1f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e2b0>],
#    't_delta': 86400},
#   71: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e430>],
#    't_delta': 86400},
#   72: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e4f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e5b0>],
#    't_delta': 86400},
#   73: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e730>],
#    't_delta': 86400},
#   74: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e7f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244e8b0>],
#    't_delta': 86400},
#   75: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244e970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244ea30>],
#    't_delta': 86400},
#   76: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244eaf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244ebb0>],
#    't_delta': 86400},
#   77: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244ec70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244ed30>],
#    't_delta': 86400},
#   78: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244edf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69244eeb0>],
#    't_delta': 86400},
#   79: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69244ef70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450070>],
#    't_delta': 86400},
#   80: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924501f0>],
#    't_delta': 86400},
#   81: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924502b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450370>],
#    't_delta': 86400},
#   82: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924504f0>],
#    't_delta': 86400},
#   83: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924505b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450670>],
#    't_delta': 86400},
#   84: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924507f0>],
#    't_delta': 86400},
#   85: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924508b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450970>],
#    't_delta': 86400},
#   86: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450a30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450af0>],
#    't_delta': 86400},
#   87: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450bb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450c70>],
#    't_delta': 86400},
#   88: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450d30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450df0>],
#    't_delta': 86400},
#   89: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692450eb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692450f70>],
#    't_delta': 86400},
#   90: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453130>],
#    't_delta': 86400},
#   91: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924531f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924532b0>],
#    't_delta': 86400},
#   92: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453430>],
#    't_delta': 86400},
#   93: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924534f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924535b0>],
#    't_delta': 86400},
#   94: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453730>],
#    't_delta': 86400},
#   95: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924537f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924538b0>],
#    't_delta': 86400},
#   96: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453a30>],
#    't_delta': 86400},
#   97: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453bb0>],
#    't_delta': 86400},
#   98: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453d30>],
#    't_delta': 86400},
#   99: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692453eb0>],
#    't_delta': 86400},
#   100: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692453f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455070>],
#    't_delta': 86400},
#   101: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924551f0>],
#    't_delta': 86400},
#   102: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924552b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455370>],
#    't_delta': 86400},
#   103: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924554f0>],
#    't_delta': 86400},
#   104: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924555b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455670>],
#    't_delta': 86400},
#   105: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924557f0>],
#    't_delta': 86400},
#   106: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924558b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455970>],
#    't_delta': 86400},
#   107: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455a30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455af0>],
#    't_delta': 86400},
#   108: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455bb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455c70>],
#    't_delta': 86400},
#   109: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455d30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455df0>],
#    't_delta': 86400},
#   110: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692455eb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692455f70>],
#    't_delta': 86400},
#   111: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459130>],
#    't_delta': 86400},
#   112: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924591f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924592b0>],
#    't_delta': 86400},
#   113: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459430>],
#    't_delta': 86400},
#   114: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924594f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924595b0>],
#    't_delta': 86400},
#   115: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459730>],
#    't_delta': 86400},
#   116: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924597f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924598b0>],
#    't_delta': 86400},
#   117: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459a30>],
#    't_delta': 86400},
#   118: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459bb0>],
#    't_delta': 86400},
#   119: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459d30>],
#    't_delta': 86400},
#   120: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692459eb0>],
#    't_delta': 86400},
#   121: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692459f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b070>],
#    't_delta': 86400},
#   122: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b1f0>],
#    't_delta': 86400},
#   123: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b2b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b370>],
#    't_delta': 86400},
#   124: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b4f0>],
#    't_delta': 86400},
#   125: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b5b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b670>],
#    't_delta': 86400},
#   126: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b7f0>],
#    't_delta': 86400},
#   127: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245b8b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245b970>],
#    't_delta': 86400},
#   128: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245ba30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245baf0>],
#    't_delta': 86400},
#   129: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245bbb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245bc70>],
#    't_delta': 86400},
#   130: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245bd30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245bdf0>],
#    't_delta': 86400},
#   131: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245beb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245bf70>],
#    't_delta': 86400},
#   132: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e130>],
#    't_delta': 86400},
#   133: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e1f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e2b0>],
#    't_delta': 86400},
#   134: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e430>],
#    't_delta': 86400},
#   135: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e4f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e5b0>],
#    't_delta': 86400},
#   136: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e730>],
#    't_delta': 86400},
#   137: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e7f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245e8b0>],
#    't_delta': 86400},
#   138: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245e970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245ea30>],
#    't_delta': 86400},
#   139: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245eaf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245ebb0>],
#    't_delta': 86400},
#   140: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245ec70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245ed30>],
#    't_delta': 86400},
#   141: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245edf0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69245eeb0>],
#    't_delta': 86400},
#   142: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69245ef70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460070>],
#    't_delta': 86400},
#   143: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924601f0>],
#    't_delta': 86400},
#   144: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924602b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460370>],
#    't_delta': 86400},
#   145: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924604f0>],
#    't_delta': 86400},
#   146: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924605b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460670>],
#    't_delta': 86400},
#   147: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924607f0>],
#    't_delta': 86400},
#   148: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924608b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460970>],
#    't_delta': 86400},
#   149: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460a30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460af0>],
#    't_delta': 86400},
#   150: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460bb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460c70>],
#    't_delta': 86400},
#   151: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460d30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460df0>],
#    't_delta': 86400},
#   152: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692460eb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692460f70>],
#    't_delta': 86400},
#   153: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462130>],
#    't_delta': 86400},
#   154: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924621f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924622b0>],
#    't_delta': 86400},
#   155: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462430>],
#    't_delta': 86400},
#   156: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924624f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924625b0>],
#    't_delta': 86400},
#   157: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462730>],
#    't_delta': 86400},
#   158: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924627f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924628b0>],
#    't_delta': 86400},
#   159: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462a30>],
#    't_delta': 86400},
#   160: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462bb0>],
#    't_delta': 86400},
#   161: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462d30>],
#    't_delta': 86400},
#   162: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692462eb0>],
#    't_delta': 86400},
#   163: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692462f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465070>],
#    't_delta': 86400},
#   164: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924651f0>],
#    't_delta': 86400},
#   165: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924652b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465370>],
#    't_delta': 86400},
#   166: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924654f0>],
#    't_delta': 86400},
#   167: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924655b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465670>],
#    't_delta': 86400},
#   168: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924657f0>],
#    't_delta': 86400},
#   169: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924658b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465970>],
#    't_delta': 86400},
#   170: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465a30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465af0>],
#    't_delta': 86400},
#   171: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465bb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465c70>],
#    't_delta': 86400},
#   172: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465d30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465df0>],
#    't_delta': 86400},
#   173: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692465eb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692465f70>],
#    't_delta': 86400},
#   174: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467130>],
#    't_delta': 86400},
#   175: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924671f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924672b0>],
#    't_delta': 86400},
#   176: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467430>],
#    't_delta': 86400},
#   177: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924674f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924675b0>],
#    't_delta': 86400},
#   178: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467730>],
#    't_delta': 86400},
#   179: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff6924677f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff6924678b0>],
#    't_delta': 86400},
#   180: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467970>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467a30>],
#    't_delta': 86400},
#   181: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467af0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467bb0>],
#    't_delta': 86400},
#   182: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467c70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467d30>],
#    't_delta': 86400},
#   183: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467df0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff692467eb0>],
#    't_delta': 86400},
#   184: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff692467f70>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a070>],
#    't_delta': 86400},
#   185: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a130>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a1f0>],
#    't_delta': 86400},
#   186: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a2b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a370>],
#    't_delta': 86400},
#   187: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a430>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a4f0>],
#    't_delta': 86400},
#   188: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a5b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a670>],
#    't_delta': 86400},
#   189: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a730>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a7f0>],
#    't_delta': 86400},
#   190: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246a8b0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246a970>],
#    't_delta': 86400},
#   191: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246aa30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246aaf0>],
#    't_delta': 86400},
#   192: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246abb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246ac70>],
#    't_delta': 86400},
#   193: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246ad30>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246adf0>],
#    't_delta': 86400},
#   194: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246aeb0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246af70>],
#    't_delta': 86400},
#   195: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246c040>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246c130>],
#    't_delta': 86400},
#   196: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246c1f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246c2b0>],
#    't_delta': 86400},
#   197: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246c370>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246c430>],
#    't_delta': 86400},
#   198: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246c4f0>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246c5b0>],
#    't_delta': 86400},
#   199: {'set': [<python.dev.action.DepositAction.DepositAction at 0x7ff69246c670>,
#     <python.dev.action.WithdrawAction.WithdrawAction at 0x7ff69246c730>],
#    't_delta': 86400}}}

# %%
batch1 = sBatch1.generate()
batch2 = sBatch2.generate()
batch3 = aBatch1.generate()
batch4 = aBatch2.generate()

q2 = EventQueue()
q2.add_event_batch(batch1)
q2.add_event_batch(batch2)
q2.add_event_batch(batch3)
q2.add_event_batch(batch4)

# %% [markdown]
# ### Execute events

# %%
orchestrator = SimulationOrchestrator(verbose = True)
executor = EventExecutor(q2, orchestrator)
executor.run()
# Out:
# ======== Action Tasks ===========
# # num_tasks: 1409
#
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# USER1 WITHDRAWs 2500.00 SYS
# USER1 WITHDRAWs 2500.00 DAI
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 5000.00 SYS
# USER2 SWAPs 2500.00 SYS for DAI
# USER2 WITHDRAWs 2500.00 from DAI proceeds
# USER2 WITHDRAWs 2500.00 SYS
# USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 DEPOSITs 4967.95 SYS
# USER2 WITHDRAWs 5015.16 SYS
# USER2 DEPOSITs 4996.17 SYS
# USER2 WITHDRAWs 4989.34 SYS
# USER2 DEPOSITs 4981.72 SYS
# USER2 WITHDRAWs 5017.13 SYS
# USER2 DEPOSITs 4981.49 SYS
# USER2 WITHDRAWs 4967.79 SYS
# USER2 DEPOSITs 4984.86 SYS
# USER2 WITHDRAWs 4983.28 SYS
# USER2 DEPOSITs 5015.64 SYS
# USER2 WITHDRAWs 4973.16 SYS
# USER2 DEPOSITs 5018.63 SYS
# USER2 WITHDRAWs 5025.78 SYS
# USER2 DEPOSITs 5010.76 SYS
# USER2 WITHDRAWs 5003.36 SYS
# USER2 DEPOSITs 4998.11 SYS
# USER2 WITHDRAWs 4997.64 SYS
# USER2 DEPOSITs 4974.83 SYS
# USER2 WITHDRAWs 5049.14 SYS
# USER2 DEPOSITs 4965.17 SYS
# USER2 WITHDRAWs 5030.07 SYS
# USER2 DEPOSITs 5012.88 SYS
# USER2 WITHDRAWs 4965.93 SYS
# USER2 DEPOSITs 5000.21 SYS
# USER2 WITHDRAWs 4980.67 SYS
# USER2 DEPOSITs 4991.18 SYS
# USER2 WITHDRAWs 5039.10 SYS
# USER2 DEPOSITs 4981.89 SYS
# USER2 WITHDRAWs 4983.14 SYS
# USER2 DEPOSITs 5018.85 SYS
# USER2 WITHDRAWs 4991.91 SYS
# USER2 DEPOSITs 5011.92 SYS
# USER2 WITHDRAWs 5028.69 SYS
# USER2 DEPOSITs 4989.36 SYS
# USER2 WITHDRAWs 4998.88 SYS
# USER2 DEPOSITs 4995.44 SYS
# USER2 WITHDRAWs 5019.84 SYS
# USER2 DEPOSITs 4973.88 SYS
# USER2 WITHDRAWs 4986.18 SYS
# USER2 DEPOSITs 5008.75 SYS
# USER2 WITHDRAWs 4994.56 SYS
# USER2 DEPOSITs 4992.40 SYS
# USER2 WITHDRAWs 5011.12 SYS
# USER2 DEPOSITs 5004.34 SYS
# USER2 WITHDRAWs 5043.33 SYS
# USER2 DEPOSITs 4999.53 SYS
# USER2 WITHDRAWs 4972.23 SYS
# USER2 DEPOSITs 5022.15 SYS
# USER2 WITHDRAWs 4983.27 SYS
# USER2 DEPOSITs 4981.78 SYS
# USER2 WITHDRAWs 5027.33 SYS
# USER2 DEPOSITs 5022.11 SYS
# USER2 WITHDRAWs 5029.18 SYS
# USER2 DEPOSITs 5020.86 SYS
# USER2 WITHDRAWs 4968.17 SYS
# USER2 DEPOSITs 5032.12 SYS
# USER2 WITHDRAWs 4984.33 SYS
# USER2 DEPOSITs 5047.59 SYS
# USER2 WITHDRAWs 4988.97 SYS
# USER2 DEPOSITs 4965.33 SYS
# USER2 WITHDRAWs 4949.70 SYS
# USER2 DEPOSITs 5016.82 SYS
# USER2 WITHDRAWs 5016.26 SYS
# USER2 DEPOSITs 4970.68 SYS
# USER2 WITHDRAWs 4971.11 SYS
# USER2 DEPOSITs 4997.77 SYS
# USER2 WITHDRAWs 5014.87 SYS
# USER2 DEPOSITs 4972.69 SYS
# USER2 WITHDRAWs 4981.00 SYS
# USER2 DEPOSITs 4995.61 SYS
# USER2 WITHDRAWs 5004.89 SYS
# USER2 DEPOSITs 4984.79 SYS
# USER2 WITHDRAWs 5008.19 SYS
# USER2 DEPOSITs 4955.63 SYS
# USER2 WITHDRAWs 5010.21 SYS
# USER2 DEPOSITs 5005.68 SYS
# USER2 WITHDRAWs 4974.75 SYS
# USER2 DEPOSITs 4970.52 SYS
# USER2 WITHDRAWs 5010.84 SYS
# USER2 DEPOSITs 4990.72 SYS
# USER2 WITHDRAWs 4991.19 SYS
# USER2 DEPOSITs 5012.44 SYS
# USER2 WITHDRAWs 5009.16 SYS
# USER2 DEPOSITs 4998.31 SYS
# USER2 WITHDRAWs 4974.13 SYS
# USER2 DEPOSITs 4990.66 SYS
# USER2 WITHDRAWs 5018.76 SYS
# USER2 DEPOSITs 4994.23 SYS
# USER2 WITHDRAWs 4980.52 SYS
# USER2 DEPOSITs 5001.47 SYS
# USER2 WITHDRAWs 4997.72 SYS
# USER2 DEPOSITs 5033.12 SYS
# USER2 WITHDRAWs 4990.81 SYS
# USER2 DEPOSITs 5009.09 SYS
# USER2 WITHDRAWs 5011.28 SYS
# USER2 DEPOSITs 5021.13 SYS
# USER2 WITHDRAWs 4981.67 SYS
# USER2 DEPOSITs 5008.95 SYS
# USER2 WITHDRAWs 5015.48 SYS
# USER2 DEPOSITs 5004.45 SYS
# USER2 WITHDRAWs 4983.90 SYS
# USER2 DEPOSITs 5011.53 SYS
# USER2 WITHDRAWs 5019.08 SYS
# USER2 DEPOSITs 5001.11 SYS
# USER2 WITHDRAWs 5004.01 SYS
# USER2 DEPOSITs 5018.94 SYS
# USER2 WITHDRAWs 4972.91 SYS
# USER2 DEPOSITs 5030.27 SYS
# USER2 WITHDRAWs 5026.01 SYS
# USER2 DEPOSITs 5004.22 SYS
# USER2 WITHDRAWs 4986.94 SYS
# USER2 DEPOSITs 4987.78 SYS
# USER2 WITHDRAWs 5000.35 SYS
# USER2 DEPOSITs 5026.45 SYS
# USER2 WITHDRAWs 5013.13 SYS
# USER2 DEPOSITs 5004.49 SYS
# USER2 WITHDRAWs 5012.10 SYS
# USER2 DEPOSITs 4968.36 SYS
# USER2 WITHDRAWs 5001.75 SYS
# USER2 DEPOSITs 4980.20 SYS
# USER2 WITHDRAWs 4995.87 SYS
# USER2 DEPOSITs 4984.16 SYS
# USER2 WITHDRAWs 4979.08 SYS
# USER2 DEPOSITs 4993.34 SYS
# USER2 WITHDRAWs 5004.35 SYS
# USER2 DEPOSITs 5016.83 SYS
# USER2 WITHDRAWs 5038.48 SYS
# USER2 DEPOSITs 5018.70 SYS
# USER2 WITHDRAWs 5019.08 SYS
# USER2 DEPOSITs 5045.62 SYS
# USER2 WITHDRAWs 5024.66 SYS
# USER2 DEPOSITs 5028.60 SYS
# USER2 WITHDRAWs 5019.45 SYS
# USER2 DEPOSITs 5004.54 SYS
# USER2 WITHDRAWs 5006.63 SYS
# USER2 DEPOSITs 5023.38 SYS
# USER2 WITHDRAWs 5011.39 SYS
# USER2 DEPOSITs 5029.65 SYS
# USER2 WITHDRAWs 4993.73 SYS
# USER2 DEPOSITs 4995.01 SYS
# USER2 WITHDRAWs 4994.89 SYS
# USER2 DEPOSITs 4995.53 SYS
# USER2 WITHDRAWs 4981.76 SYS
# USER2 DEPOSITs 4958.99 SYS
# USER2 WITHDRAWs 5009.19 SYS
# USER2 DEPOSITs 5030.32 SYS
# USER2 WITHDRAWs 4974.44 SYS
# USER2 DEPOSITs 4997.81 SYS
# USER2 WITHDRAWs 4991.54 SYS
# USER2 DEPOSITs 5023.10 SYS
# USER2 WITHDRAWs 5021.80 SYS
# USER2 DEPOSITs 5013.11 SYS
# USER2 WITHDRAWs 4961.30 SYS
# USER2 DEPOSITs 4961.33 SYS
# USER2 WITHDRAWs 5010.87 SYS
# USER2 DEPOSITs 4987.02 SYS
# USER2 WITHDRAWs 5006.13 SYS
# USER2 DEPOSITs 4982.97 SYS
# USER2 WITHDRAWs 4978.36 SYS
# USER2 DEPOSITs 4977.68 SYS
# USER2 WITHDRAWs 4986.42 SYS
# USER2 DEPOSITs 5012.88 SYS
# USER2 WITHDRAWs 5000.12 SYS
# USER2 DEPOSITs 5012.55 SYS
# USER2 WITHDRAWs 5014.30 SYS
# USER2 DEPOSITs 5033.60 SYS
# USER2 WITHDRAWs 5007.90 SYS
# USER2 DEPOSITs 5004.08 SYS
# USER2 WITHDRAWs 4988.83 SYS
# USER2 DEPOSITs 5008.95 SYS
# USER2 WITHDRAWs 4950.69 SYS
# USER2 DEPOSITs 5034.50 SYS
# USER2 WITHDRAWs 5013.47 SYS
# USER2 DEPOSITs 4994.84 SYS
# USER2 WITHDRAWs 5009.52 SYS
# USER2 DEPOSITs 4981.28 SYS
# USER2 WITHDRAWs 5023.80 SYS
# USER2 DEPOSITs 5000.75 SYS
# USER2 WITHDRAWs 4999.18 SYS
# USER2 DEPOSITs 5044.64 SYS
# USER2 WITHDRAWs 4977.03 SYS
# USER2 DEPOSITs 4993.53 SYS
# USER2 WITHDRAWs 5010.51 SYS
# USER2 DEPOSITs 4960.82 SYS
# USER2 WITHDRAWs 5007.12 SYS
# USER2 DEPOSITs 5020.39 SYS
# USER2 WITHDRAWs 5007.27 SYS
# USER2 DEPOSITs 5006.43 SYS
# USER2 WITHDRAWs 4997.55 SYS
# USER2 DEPOSITs 4980.23 SYS
# USER2 WITHDRAWs 4992.77 SYS
# USER2 DEPOSITs 5007.11 SYS
# USER2 WITHDRAWs 4975.30 SYS
# USER2 DEPOSITs 4994.92 SYS
# USER2 WITHDRAWs 4986.80 SYS
# USER2 DEPOSITs 5028.41 SYS
# USER2 WITHDRAWs 4991.84 SYS
# USER2 DEPOSITs 4979.85 SYS
# USER2 WITHDRAWs 5010.45 SYS
# USER2 DEPOSITs 5019.93 SYS
# USER2 WITHDRAWs 5021.57 SYS
# USER2 DEPOSITs 5038.67 SYS
# USER2 WITHDRAWs 4983.03 SYS
# USER2 DEPOSITs 4978.74 SYS
# USER2 WITHDRAWs 4958.64 SYS
# USER2 DEPOSITs 4988.91 SYS
# USER2 WITHDRAWs 4980.79 SYS
# USER2 DEPOSITs 4982.11 SYS
# USER2 WITHDRAWs 4993.63 SYS
# USER2 DEPOSITs 4994.95 SYS
# USER2 WITHDRAWs 5025.47 SYS
# USER2 DEPOSITs 5000.88 SYS
# USER2 WITHDRAWs 4993.92 SYS
# USER2 DEPOSITs 4936.45 SYS
# USER2 WITHDRAWs 5009.14 SYS
# USER2 DEPOSITs 5009.08 SYS
# USER2 WITHDRAWs 4949.14 SYS
# USER2 DEPOSITs 5021.35 SYS
# USER2 WITHDRAWs 4993.14 SYS
# USER2 DEPOSITs 4980.02 SYS
# USER2 WITHDRAWs 4988.13 SYS
# USER2 DEPOSITs 5005.61 SYS
# USER2 WITHDRAWs 5034.88 SYS
# USER2 DEPOSITs 5038.45 SYS
# USER2 WITHDRAWs 5003.56 SYS
# USER2 DEPOSITs 4999.27 SYS
# USER2 WITHDRAWs 5031.16 SYS
# USER2 DEPOSITs 5020.47 SYS
# USER2 WITHDRAWs 4966.83 SYS
# USER2 DEPOSITs 4985.53 SYS
# USER2 WITHDRAWs 4976.52 SYS
# USER2 DEPOSITs 4985.84 SYS
# USER2 WITHDRAWs 5008.33 SYS
# USER2 DEPOSITs 5003.60 SYS
# USER2 WITHDRAWs 5024.46 SYS
# USER2 DEPOSITs 5001.77 SYS
# USER2 WITHDRAWs 4986.76 SYS
# USER2 DEPOSITs 5025.17 SYS
# USER2 WITHDRAWs 4992.97 SYS
# USER2 DEPOSITs 4986.07 SYS
# USER2 WITHDRAWs 5011.48 SYS
# USER2 DEPOSITs 4997.63 SYS
# USER2 WITHDRAWs 5007.25 SYS
# USER2 DEPOSITs 5006.96 SYS
# USER2 WITHDRAWs 4986.22 SYS
# USER2 DEPOSITs 5005.90 SYS
# USER2 WITHDRAWs 4966.02 SYS
# USER2 DEPOSITs 4986.10 SYS
# USER2 WITHDRAWs 5003.83 SYS
# USER2 DEPOSITs 5027.88 SYS
# USER2 WITHDRAWs 4993.63 SYS
# USER2 DEPOSITs 4994.73 SYS
# USER2 WITHDRAWs 4991.62 SYS
# USER2 DEPOSITs 5006.25 SYS
# USER2 WITHDRAWs 4988.61 SYS
# USER2 DEPOSITs 5024.22 SYS
# USER2 WITHDRAWs 5029.33 SYS
# USER2 DEPOSITs 5032.78 SYS
# USER2 WITHDRAWs 5009.55 SYS
# USER2 DEPOSITs 4997.98 SYS
# USER2 WITHDRAWs 4966.22 SYS
# USER2 DEPOSITs 5017.54 SYS
# USER2 WITHDRAWs 4977.78 SYS
# USER2 DEPOSITs 4958.72 SYS
# USER2 WITHDRAWs 5018.63 SYS
# USER2 DEPOSITs 4986.95 SYS
# USER2 WITHDRAWs 4984.20 SYS
# USER2 DEPOSITs 4991.86 SYS
# USER2 WITHDRAWs 4998.54 SYS
# USER2 DEPOSITs 5013.41 SYS
# USER2 WITHDRAWs 4993.34 SYS
# USER2 DEPOSITs 5018.91 SYS
# USER2 WITHDRAWs 5029.41 SYS
# USER2 DEPOSITs 4981.77 SYS
# USER2 WITHDRAWs 4982.19 SYS
# USER2 DEPOSITs 5001.99 SYS
# USER2 WITHDRAWs 4986.09 SYS
# USER2 DEPOSITs 5011.67 SYS
# USER2 WITHDRAWs 4970.36 SYS
# USER2 DEPOSITs 4962.55 SYS
# USER2 WITHDRAWs 4997.52 SYS
# USER2 DEPOSITs 4997.64 SYS
# USER2 WITHDRAWs 4999.49 SYS
# USER2 DEPOSITs 5010.01 SYS
# USER2 WITHDRAWs 5004.45 SYS
# USER2 DEPOSITs 5011.89 SYS
# USER2 WITHDRAWs 4982.69 SYS
# USER2 DEPOSITs 4971.14 SYS
# USER2 WITHDRAWs 5035.34 SYS
# USER2 DEPOSITs 4974.84 SYS
# USER2 WITHDRAWs 5001.82 SYS
# USER2 DEPOSITs 5009.20 SYS
# USER2 WITHDRAWs 4981.72 SYS
# USER2 DEPOSITs 4987.73 SYS
# USER2 WITHDRAWs 4994.20 SYS
# USER2 DEPOSITs 5010.90 SYS
# USER2 WITHDRAWs 5003.01 SYS
# USER2 DEPOSITs 4989.10 SYS
# USER2 WITHDRAWs 4997.77 SYS
# USER2 DEPOSITs 4983.86 SYS
# USER2 WITHDRAWs 4985.12 SYS
# USER2 DEPOSITs 4987.77 SYS
# USER2 WITHDRAWs 4991.01 SYS
# USER2 DEPOSITs 5008.83 SYS
# USER2 WITHDRAWs 5012.62 SYS
# USER2 DEPOSITs 4984.17 SYS
# USER2 WITHDRAWs 4994.46 SYS
# USER2 DEPOSITs 4981.45 SYS
# USER2 WITHDRAWs 4994.49 SYS
# USER2 DEPOSITs 5027.76 SYS
# USER2 WITHDRAWs 5017.59 SYS
# USER2 DEPOSITs 5002.65 SYS
# USER2 WITHDRAWs 5000.55 SYS
# USER2 DEPOSITs 4999.59 SYS
# USER2 WITHDRAWs 4996.53 SYS
# USER2 DEPOSITs 4991.45 SYS
# USER2 WITHDRAWs 5035.66 SYS
# USER2 DEPOSITs 4989.14 SYS
# USER2 WITHDRAWs 5002.56 SYS
# USER2 DEPOSITs 4969.22 SYS
# USER2 WITHDRAWs 4994.51 SYS
# USER2 DEPOSITs 4992.15 SYS
# USER2 WITHDRAWs 4995.98 SYS
# USER2 DEPOSITs 5000.96 SYS
# USER2 WITHDRAWs 5044.67 SYS
# USER2 DEPOSITs 4986.12 SYS
# USER2 WITHDRAWs 4982.58 SYS
# USER2 DEPOSITs 4991.78 SYS
# USER2 WITHDRAWs 4992.25 SYS
# USER2 DEPOSITs 5022.81 SYS
# USER2 WITHDRAWs 5011.08 SYS
# USER2 DEPOSITs 4994.38 SYS
# USER2 WITHDRAWs 5004.67 SYS
# USER2 DEPOSITs 5038.09 SYS
# USER2 WITHDRAWs 5013.47 SYS
# USER2 DEPOSITs 4998.33 SYS
# USER2 WITHDRAWs 5022.14 SYS
# USER2 DEPOSITs 4987.16 SYS
# USER2 WITHDRAWs 5041.29 SYS
# USER2 DEPOSITs 5003.40 SYS
# USER2 WITHDRAWs 4996.75 SYS
# USER2 DEPOSITs 5013.18 SYS
# USER2 WITHDRAWs 5001.71 SYS
# USER2 DEPOSITs 4990.89 SYS
# USER2 WITHDRAWs 5017.98 SYS
# USER2 DEPOSITs 5014.84 SYS
# USER2 WITHDRAWs 4988.71 SYS
# USER2 DEPOSITs 5023.35 SYS
# USER2 WITHDRAWs 5059.92 SYS
# USER2 DEPOSITs 4991.92 SYS
# USER2 WITHDRAWs 5035.14 SYS
# USER2 DEPOSITs 5033.92 SYS
# USER2 WITHDRAWs 5012.08 SYS
# USER2 DEPOSITs 5010.85 SYS
# USER2 WITHDRAWs 4995.96 SYS
# USER2 DEPOSITs 4991.05 SYS
# USER2 WITHDRAWs 5019.05 SYS
# USER2 DEPOSITs 5007.93 SYS
# USER2 WITHDRAWs 4983.02 SYS
# USER2 DEPOSITs 5032.77 SYS
# USER2 WITHDRAWs 5002.40 SYS
# USER2 DEPOSITs 4980.53 SYS
# USER2 WITHDRAWs 5027.16 SYS
# USER2 DEPOSITs 4996.20 SYS
# USER2 WITHDRAWs 4998.17 SYS
# USER2 DEPOSITs 4977.83 SYS
# USER2 WITHDRAWs 4984.75 SYS
# USER2 DEPOSITs 4991.24 SYS
# USER2 WITHDRAWs 5011.79 SYS
# USER2 DEPOSITs 5000.69 SYS
# USER2 WITHDRAWs 4983.40 SYS
# USER2 DEPOSITs 5036.06 SYS
# USER2 WITHDRAWs 5013.13 SYS
# USER2 DEPOSITs 4999.93 SYS
# USER2 WITHDRAWs 5010.48 SYS
# USER2 DEPOSITs 5013.07 SYS
# USER2 WITHDRAWs 5016.55 SYS
# USER2 DEPOSITs 5019.16 SYS
# USER2 WITHDRAWs 4969.97 SYS
# USER2 DEPOSITs 4999.61 SYS
# USER2 WITHDRAWs 4997.88 SYS
# USER2 DEPOSITs 4995.36 SYS
# USER2 WITHDRAWs 4994.42 SYS
# USER2 DEPOSITs 5008.11 SYS
# USER2 WITHDRAWs 4995.57 SYS
# USER2 DEPOSITs 5024.81 SYS
# USER2 WITHDRAWs 4994.33 SYS
# USER2 DEPOSITs 4967.56 SYS
# USER2 WITHDRAWs 5045.23 SYS
# USER2 DEPOSITs 4996.91 SYS
# USER2 WITHDRAWs 5017.35 SYS
# USER2 DEPOSITs 4987.75 SYS
# USER2 WITHDRAWs 4944.52 SYS
# USER2 DEPOSITs 5016.59 SYS
# USER2 WITHDRAWs 4972.69 SYS
# USER2 DEPOSITs 5039.93 SYS
# USER2 WITHDRAWs 4982.40 SYS
# USER2 DEPOSITs 4994.03 SYS
# USER2 WITHDRAWs 4945.25 SYS

# %% [markdown]
# ### Analyze

# %%
tSYS = SYS.get_token()
tDAI = DAI.get_token()
tSYS_DAI = SYS_DAI.get_token()

SYS_addr1 = SYS.get_address(SYS_mint1.get_id())
DAI_addr1 = DAI.get_address(DAI_mint1.get_id())
SYS_DAI_addr1 = SYS_DAI.get_address(SYS_DAI_LP_mint1.get_id())

# %%
SYS_states1 = tSYS.get_state_series(SYS_addr1)
principle = SYS_states1.get_principle() 
balance = SYS_states1.get_balance() 
tSamp = SYS_states1.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_ax.set_title("USER1: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states1 = tDAI.get_state_series(DAI_addr1)
principle = DAI_states1.get_principle() 
balance = DAI_states1.get_balance() 
tSamp = DAI_states1.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER1: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states1 = tSYS_DAI.get_state_series(SYS_DAI_addr1)
principle = SYS_DAI_states1.get_principle() 
balance = SYS_DAI_states1.get_balance() 
tSamp = SYS_DAI_states1.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
SYS_addr2 = SYS.get_address(SYS_mint2.get_id())
DAI_addr2 = DAI.get_address(DAI_mint2.get_id())
SYS_DAI_addr2 = SYS_DAI.get_address(SYS_DAI_LP_mint2.get_id())

# %%
SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp()

# %%
# Analyze Token balances

SYS_states2 = tSYS.get_state_series(SYS_addr2)
principle = SYS_states2.get_principle() 
balance = SYS_states2.get_balance() 
tSamp = SYS_states2.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp, balance, label='balance') 
SYS_ax.plot(tSamp, principle, label='principle') 
SYS_ax.set_title("USER2: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states2 = tDAI.get_state_series(DAI_addr2)
principle = DAI_states2.get_principle() 
balance = DAI_states2.get_balance() 
tSamp = DAI_states2.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER2: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
tSamp = SYS_DAI_LP.get_lp_events().get_dates()
utSamp = SYS_DAI_LP.get_lp_events().get_unix_time_stamps()
prices = SYS_DAI_LP.get_lp_events().get_prices()
liquidities = SYS_DAI_LP.get_lp_events().get_liquidity_values()
balances = SYS_DAI_LP.get_lp_events().gen_yield_balances(apy)

fig, (liq_ax) = plt.subplots(nrows=1, sharex=True, sharey=False, figsize=(18, 15))

liq_ax.plot(tSamp, liquidities, label='liquidities') 
liq_ax.plot(tSamp, balances, label='liquidities') 
liq_ax.set_title("Total SYS_DAI_LP Balance (rebasing token)", fontsize=20)
liq_ax.set_ylabel("Token balance", fontsize=16)
liq_ax.set_xlabel('Time', fontsize=16)
liq_ax.legend()
