# %% [markdown]
# ### Simulation: Masternode Yield Farming

# %%
import os
import copy
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from IPython.display import Image
cwd =  os.getcwd().replace("notebooks/simulation","")
os.chdir(cwd)

from python.dev.helper import Helper

from python.dev.simulation import SimulationOrchestrator
from python.dev.simulation import EventQueue
from python.dev.simulation import EventExecutor
from python.dev.simulation.batch import ActionBatch
from python.dev.simulation.batch import MergeBatch

from python.dev.agent import TokenAgent
from python.dev.agent import LPTokenAgent
from python.dev.agent import UserAgent

from python.dev.action import MintAction
from python.dev.action import DepositAction
from python.dev.action import LPDepositChainAction
from python.dev.action import DepositChainAction
from python.dev.action import WithdrawChainAction
from python.dev.action import WithdrawAction
from python.dev.action import SwapAction
from python.dev.event import Mint
from python.dev.event import Deposit
from python.dev.event import Withdraw
from python.dev.event import Swap

from python.dev.math.model import TokenDeltaModel
from python.dev.math.model import TimeDeltaModel
from python.dev.math.model import ModelQueue

from python.dev.lp import LiquidityPool
from python.dev.lp.event import LPEvent
from python.dev.lp.event import MintLPEvent
from python.dev.lp.event import DepositLPEvent
from python.dev.lp.event import SwapLPEvent

# %%
Image("images/jupyter/tutorials/masternode_nft.png", width = 600, height = 600)

# %% [markdown]
# ### Load Data

# %%
daosys_proj = pd.read_csv('notebooks/resources/daosys_proj.csv')

# %% [markdown]
# ### Initialize Agents

# %%
USER1 = UserAgent('USER1')
USER2 = UserAgent('USER2')

SYS = TokenAgent('SYS')
DAI = TokenAgent('DAI')

SYS_DAI_LP = LiquidityPool('SYS/DAI', USER1, SYS, DAI)
SYS_DAI = LPTokenAgent('SYS_DAI_LP', SYS_DAI_LP)

# %% [markdown]
# ### Mint Tokens

# %%
apy = 0.1
t_delta = 109*24*3600

# %%
SYS_mint1 = Mint(5000, apy, True)
DAI_mint1 = Mint(5000, apy, True)
SYS_DAI_LP_mint1 = Mint(0, apy, True)

SYS_mint2 = Mint(100000, apy, True)
DAI_mint2 = Mint(0, apy, True)
SYS_mint3 = Mint(1000, apy, True)
SYS_DAI_LP_mint2 = Mint(0, apy, True)

# %%
m_action1 = MintAction(SYS_mint1, SYS, USER1)
m_action2 = MintAction(DAI_mint1, DAI, USER1)
m_action3 = MintAction(SYS_DAI_LP_mint1, SYS_DAI, USER1)

m_action4 = MintAction(SYS_mint2, SYS, USER2)
m_action5 = MintAction(DAI_mint2, DAI, USER2)
m_action6 = MintAction(SYS_DAI_LP_mint2, SYS_DAI, USER2)
m_action7 = MintAction(SYS_mint3, SYS, USER1)

# %% [markdown]
# ### Setup Actions

# %%
sub_withdraw1 = Withdraw(apy, 2500, 0) 
sub_withdraw2 = Withdraw(apy, 2500, 0) 
w_action1 = WithdrawAction(sub_withdraw1, SYS, USER1, SYS_mint1.get_id())
w_action2 = WithdrawAction(sub_withdraw2, DAI, USER1, DAI_mint1.get_id())
d_action1 = LPDepositChainAction(w_action1, w_action2, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 1

# %%
deposit_obj1 = ModelQueue().apply(daosys_proj['mn_nsys'].values, 200)
withdraw_obj2 = ModelQueue().apply(daosys_proj['mn_nsys'].values/2, 200)
t_delta_model = TimeDeltaModel().apply(p = 0.00001, n = 200)
t_delta_obj1 = ModelQueue().apply(t_delta_model)
t_delta_obj2 = ModelQueue().apply(t_delta_model)
t_delta = 3600*24

# %%
deposit1 = Deposit(apy, deposit_obj1, t_delta_obj1) 
sub_withdraw1 = Withdraw(apy, 2500, 0)
sub_deposit1 = Deposit(apy, withdraw_obj2, t_delta_obj2)
withdraw1 = Withdraw(apy, 2500, 0)

# %%
# Deposit 5000 SYS
d_action2 = DepositAction(deposit1, SYS, USER2, SYS_mint2.get_id())

# Swap 2500 SYS for DAI
sub_w_action1 = WithdrawAction(sub_withdraw1, SYS, USER2, SYS_mint2.get_id())
sub_d_action1 = DepositAction(sub_deposit1, DAI, USER2, DAI_mint2.get_id())
s_action1 = SwapAction(sub_w_action1, sub_d_action1)

# Withdraw DAI proceeds and 2500 SYS
w_action3 = WithdrawChainAction(s_action1, DAI, USER2, DAI_mint2.get_id())
w_action4 = WithdrawAction(withdraw1, SYS, USER2, SYS_mint2.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action3 = LPDepositChainAction(w_action3, w_action4, SYS_DAI, USER1, SYS_DAI_LP_mint2.get_id())

# %% [markdown]
# ### Batchset 2

# %%
r_deposit_obj = ModelQueue().apply(np.random.normal(50, 5, 200))
r_withdraw_obj = ModelQueue().apply(np.random.normal(25, 5, 200))

r_swap_model = np.random.normal(25, 5, 200)
r_sub_withdraw_obj = ModelQueue().apply(r_swap_model)
r_sub_deposit_obj = ModelQueue().apply(r_swap_model)

t_delta_model = TimeDeltaModel().apply(p = 0.00001, n = 200)
t_delta_obj3 = ModelQueue().apply(t_delta_model)
t_delta_obj4 = ModelQueue().apply(t_delta_model)

deposit2 = Deposit(apy, r_deposit_obj, t_delta_obj3) 
sub_withdraw2 = Withdraw(apy, r_sub_withdraw_obj, 0)
sub_deposit2 = Deposit(apy, r_sub_deposit_obj, t_delta_obj4)
withdraw2 = Withdraw(apy, r_withdraw_obj, 0)

# %%
# Deposit 50 SYS
d_action4 = DepositAction(deposit2, SYS, USER1, SYS_mint1.get_id())

# Swap 2500 SYS for DAI
sub_w_action2 = WithdrawAction(sub_withdraw2, SYS, USER1, SYS_mint1.get_id())
sub_d_action2 = DepositAction(sub_deposit2, DAI, USER1, DAI_mint1.get_id())
s_action2 = SwapAction(sub_w_action2, sub_d_action2)

# Withdraw DAI proceeds and 2500 SYS
w_action5 = WithdrawChainAction(s_action2, DAI, USER1, DAI_mint1.get_id())
w_action6 = WithdrawAction(withdraw2, SYS, USER1, SYS_mint1.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action5 = LPDepositChainAction(w_action5, w_action6, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %% [markdown]
# ### Batchset 3

# %%
r_deposit_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))
r_withdraw_obj = ModelQueue().apply(np.random.normal(5000, 20, 200))

deposit1a = Deposit(apy, r_deposit_obj, t_delta) 
withdraw1a = Withdraw(apy, r_withdraw_obj, 0) 

d_action1a = DepositAction(deposit1a, SYS, USER1, SYS_mint3.get_id())
w_action1a = WithdrawAction(withdraw1a, SYS, USER1, SYS_mint3.get_id())

# %%
aBatch3 = ActionBatch('RUN3', 100)
aBatch3.add_action(d_action1a)
aBatch3.add_action(w_action1a)
aBatch3.inspect()
# Out:
#  ** BATCH **
# USER1 DEPOSITs SYS
# USER1 WITHDRAWs SYS
#
#  ** REPEAT BATCH **
#  100 times
#
#  ** RUNTIME for 1st BATCH **
# 86400 seconds

# %% [markdown]
# ### Setup Batch 1

# %%
sBatch1 = ActionBatch('SETUP1')
sBatch1.init_action(m_action1)
sBatch1.init_action(m_action2)
sBatch1.init_action(m_action3)
sBatch1.init_action(w_action1)
sBatch1.init_action(w_action2)
sBatch1.init_action(d_action1)
sBatch1.inspect()
# Out:
# ** SETUP **
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# USER1 WITHDRAWs SYS
# USER1 WITHDRAWs DAI
# USER1 DEPOSITs SYS and DAI proceeds into SYS_DAI_LP

# %%
sBatch2 = ActionBatch('SETUP2')
sBatch2.init_action(m_action4)
sBatch2.init_action(m_action5)
sBatch2.init_action(m_action6)
sBatch2.init_action(m_action7)
sBatch2.inspect()
# Out:
# ** SETUP **
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS

# %%
aBatch1 = ActionBatch('RUN1', 200)
aBatch1.add_action(d_action2)
aBatch1.add_action(s_action1)
aBatch1.add_action(w_action3)
aBatch1.add_action(w_action4)
aBatch1.add_action(d_action3)
aBatch1.inspect()
# Out:
#  ** BATCH **
# USER2 DEPOSITs SYS
# USER2 SWAPs SYS for DAI
# USER2 WITHDRAWs DAI proceeds
# USER2 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 264158 seconds

# %%
aBatch2 = ActionBatch('RUN2', 200)
aBatch2.add_action(d_action4)
aBatch2.add_action(s_action2)
aBatch2.add_action(w_action5)
aBatch2.add_action(w_action6)
aBatch2.add_action(d_action5)
aBatch2.inspect()
# Out:
#  ** BATCH **
# USER1 DEPOSITs SYS
# USER1 SWAPs SYS for DAI
# USER1 WITHDRAWs DAI proceeds
# USER1 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 86400 seconds

# %%
batch1 = sBatch1.generate()
batch2 = sBatch2.generate()
batch3 = aBatch1.generate()
batch4 = aBatch2.generate()

# %%
mb = MergeBatch('RUN1RUN2')
mb.add(batch3)
mb.add(batch4)
batch_merge = mb.merge()

# %%
q2 = EventQueue()
q2.add_event_batch(batch1)
q2.add_event_batch(batch2)
q2.add_event_batch(batch_merge)

# %% [markdown]
# ### Execute events

# %%
orchestrator = SimulationOrchestrator(verbose = True)
executor = EventExecutor(q2, orchestrator)
executor.run()
# Out:
# ======== Action Tasks ===========
# # num_tasks: 2010
#
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# [2022-08-18 14:39:31] USER1 WITHDRAWs 2500.00 SYS
# [2022-08-18 14:39:31] USER1 WITHDRAWs 2500.00 DAI
# [2022-08-18 14:39:31] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS
# [2022-08-19 14:39:31] USER1 DEPOSITs 44.03 SYS
# [2022-08-19 14:39:31] USER1 SWAPs 25.70 SYS for DAI
# [2022-08-19 14:39:31] USER1 WITHDRAWs 25.70 from DAI proceeds
# [2022-08-19 14:39:31] USER1 WITHDRAWs 21.43 SYS
# [2022-08-19 14:39:31] USER1 DEPOSITs 21.43 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-20 14:39:31] USER1 DEPOSITs 51.11 SYS
# [2022-08-20 14:39:31] USER1 SWAPs 31.03 SYS for DAI
# [2022-08-20 14:39:31] USER1 WITHDRAWs 31.03 from DAI proceeds
# [2022-08-20 14:39:31] USER1 WITHDRAWs 20.45 SYS
# [2022-08-20 14:39:31] USER1 DEPOSITs 20.45 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-21 14:39:31] USER1 DEPOSITs 53.61 SYS
# [2022-08-21 14:39:31] USER1 SWAPs 21.59 SYS for DAI
# [2022-08-21 14:39:31] USER1 WITHDRAWs 21.59 from DAI proceeds
# [2022-08-21 14:39:31] USER1 WITHDRAWs 23.23 SYS
# [2022-08-21 14:39:31] USER1 DEPOSITs 23.23 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-21 16:02:09] USER2 DEPOSITs 5551.09 SYS
# [2022-08-21 16:02:09] USER2 SWAPs 2775.55 SYS for DAI
# [2022-08-21 16:02:09] USER2 WITHDRAWs 2775.55 from DAI proceeds
# [2022-08-21 16:02:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-21 16:02:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-22 14:39:31] USER1 DEPOSITs 49.99 SYS
# [2022-08-22 14:39:31] USER1 SWAPs 28.19 SYS for DAI
# [2022-08-22 14:39:31] USER1 WITHDRAWs 28.19 from DAI proceeds
# [2022-08-22 14:39:31] USER1 WITHDRAWs 21.08 SYS
# [2022-08-22 14:39:31] USER1 DEPOSITs 21.08 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-23 14:39:31] USER1 DEPOSITs 53.37 SYS
# [2022-08-23 14:39:31] USER1 SWAPs 33.43 SYS for DAI
# [2022-08-23 14:39:31] USER1 WITHDRAWs 33.43 from DAI proceeds
# [2022-08-23 14:39:31] USER1 WITHDRAWs 23.99 SYS
# [2022-08-23 14:39:31] USER1 DEPOSITs 23.99 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-24 04:18:51] USER2 DEPOSITs 5550.67 SYS
# [2022-08-24 04:18:51] USER2 SWAPs 2775.33 SYS for DAI
# [2022-08-24 04:18:51] USER2 WITHDRAWs 2775.33 from DAI proceeds
# [2022-08-24 04:18:51] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-24 04:18:51] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-24 09:48:34] USER2 DEPOSITs 5550.24 SYS
# [2022-08-24 09:48:34] USER2 SWAPs 2775.12 SYS for DAI
# [2022-08-24 09:48:34] USER2 WITHDRAWs 2775.12 from DAI proceeds
# [2022-08-24 09:48:34] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-24 09:48:34] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-24 14:39:31] USER1 DEPOSITs 41.72 SYS
# [2022-08-24 14:39:31] USER1 SWAPs 23.30 SYS for DAI
# [2022-08-24 14:39:31] USER1 WITHDRAWs 23.30 from DAI proceeds
# [2022-08-24 14:39:31] USER1 WITHDRAWs 24.16 SYS
# [2022-08-24 14:39:31] USER1 DEPOSITs 24.16 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-25 03:57:31] USER2 DEPOSITs 5549.81 SYS
# [2022-08-25 03:57:31] USER2 SWAPs 2774.90 SYS for DAI
# [2022-08-25 03:57:31] USER2 WITHDRAWs 2774.90 from DAI proceeds
# [2022-08-25 03:57:31] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-25 03:57:31] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-25 13:14:59] USER2 DEPOSITs 5549.38 SYS
# [2022-08-25 13:14:59] USER2 SWAPs 2774.69 SYS for DAI
# [2022-08-25 13:14:59] USER2 WITHDRAWs 2774.69 from DAI proceeds
# [2022-08-25 13:14:59] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-25 13:14:59] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-25 14:39:31] USER1 DEPOSITs 56.55 SYS
# [2022-08-25 14:39:31] USER1 SWAPs 21.80 SYS for DAI
# [2022-08-25 14:39:31] USER1 WITHDRAWs 21.80 from DAI proceeds
# [2022-08-25 14:39:31] USER1 WITHDRAWs 25.13 SYS
# [2022-08-25 14:39:31] USER1 DEPOSITs 25.13 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-26 14:39:31] USER1 DEPOSITs 43.50 SYS
# [2022-08-26 14:39:31] USER1 SWAPs 26.93 SYS for DAI
# [2022-08-26 14:39:31] USER1 WITHDRAWs 26.93 from DAI proceeds
# [2022-08-26 14:39:31] USER1 WITHDRAWs 29.96 SYS
# [2022-08-26 14:39:31] USER1 DEPOSITs 29.96 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-26 16:37:09] USER2 DEPOSITs 5548.95 SYS
# [2022-08-26 16:37:09] USER2 SWAPs 2774.48 SYS for DAI
# [2022-08-26 16:37:09] USER2 WITHDRAWs 2774.48 from DAI proceeds
# [2022-08-26 16:37:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-26 16:37:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-27 14:39:31] USER1 DEPOSITs 53.71 SYS
# [2022-08-27 14:39:31] USER1 SWAPs 17.83 SYS for DAI
# [2022-08-27 14:39:31] USER1 WITHDRAWs 17.83 from DAI proceeds
# [2022-08-27 14:39:31] USER1 WITHDRAWs 20.16 SYS
# [2022-08-27 14:39:31] USER1 DEPOSITs 20.16 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-28 02:24:57] USER2 DEPOSITs 5548.53 SYS
# [2022-08-28 02:24:57] USER2 SWAPs 2774.26 SYS for DAI
# [2022-08-28 02:24:57] USER2 WITHDRAWs 2774.26 from DAI proceeds
# [2022-08-28 02:24:57] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-28 02:24:57] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-28 14:39:31] USER1 DEPOSITs 54.39 SYS
# [2022-08-28 14:39:31] USER1 SWAPs 26.60 SYS for DAI
# [2022-08-28 14:39:31] USER1 WITHDRAWs 26.60 from DAI proceeds
# [2022-08-28 14:39:31] USER1 WITHDRAWs 26.66 SYS
# [2022-08-28 14:39:31] USER1 DEPOSITs 26.66 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-28 17:55:20] USER2 DEPOSITs 5548.10 SYS
# [2022-08-28 17:55:20] USER2 SWAPs 2774.05 SYS for DAI
# [2022-08-28 17:55:20] USER2 WITHDRAWs 2774.05 from DAI proceeds
# [2022-08-28 17:55:20] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-28 17:55:20] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-29 14:39:31] USER1 DEPOSITs 45.39 SYS
# [2022-08-29 14:39:31] USER1 SWAPs 21.62 SYS for DAI
# [2022-08-29 14:39:31] USER1 WITHDRAWs 21.62 from DAI proceeds
# [2022-08-29 14:39:31] USER1 WITHDRAWs 28.07 SYS
# [2022-08-29 14:39:31] USER1 DEPOSITs 28.07 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-30 14:39:31] USER1 DEPOSITs 40.92 SYS
# [2022-08-30 14:39:31] USER1 SWAPs 23.22 SYS for DAI
# [2022-08-30 14:39:31] USER1 WITHDRAWs 23.22 from DAI proceeds
# [2022-08-30 14:39:31] USER1 WITHDRAWs 17.96 SYS
# [2022-08-30 14:39:31] USER1 DEPOSITs 17.96 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-31 14:39:31] USER1 DEPOSITs 52.39 SYS
# [2022-08-31 14:39:31] USER1 SWAPs 18.67 SYS for DAI
# [2022-08-31 14:39:31] USER1 WITHDRAWs 18.67 from DAI proceeds
# [2022-08-31 14:39:31] USER1 WITHDRAWs 22.68 SYS
# [2022-08-31 14:39:31] USER1 DEPOSITs 22.68 SYS_DAI_LP from SYS and DAI proceeds
# [2022-08-31 17:46:09] USER2 DEPOSITs 5547.67 SYS
# [2022-08-31 17:46:09] USER2 SWAPs 2773.84 SYS for DAI
# [2022-08-31 17:46:09] USER2 WITHDRAWs 2773.84 from DAI proceeds
# [2022-08-31 17:46:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-08-31 17:46:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-01 14:39:31] USER1 DEPOSITs 58.04 SYS
# [2022-09-01 14:39:31] USER1 SWAPs 28.61 SYS for DAI
# [2022-09-01 14:39:31] USER1 WITHDRAWs 28.61 from DAI proceeds
# [2022-09-01 14:39:31] USER1 WITHDRAWs 23.64 SYS
# [2022-09-01 14:39:31] USER1 DEPOSITs 23.64 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-02 11:25:49] USER2 DEPOSITs 5547.24 SYS
# [2022-09-02 11:25:49] USER2 SWAPs 2773.62 SYS for DAI
# [2022-09-02 11:25:49] USER2 WITHDRAWs 2773.62 from DAI proceeds
# [2022-09-02 11:25:49] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-02 11:25:49] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-02 14:39:31] USER1 DEPOSITs 53.29 SYS
# [2022-09-02 14:39:31] USER1 SWAPs 20.05 SYS for DAI
# [2022-09-02 14:39:31] USER1 WITHDRAWs 20.05 from DAI proceeds
# [2022-09-02 14:39:31] USER1 WITHDRAWs 27.13 SYS
# [2022-09-02 14:39:31] USER1 DEPOSITs 27.13 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-03 14:39:31] USER1 DEPOSITs 63.60 SYS
# [2022-09-03 14:39:31] USER1 SWAPs 34.37 SYS for DAI
# [2022-09-03 14:39:31] USER1 WITHDRAWs 34.37 from DAI proceeds
# [2022-09-03 14:39:31] USER1 WITHDRAWs 20.11 SYS
# [2022-09-03 14:39:31] USER1 DEPOSITs 20.11 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-04 04:54:08] USER2 DEPOSITs 5546.82 SYS
# [2022-09-04 04:54:08] USER2 SWAPs 2773.41 SYS for DAI
# [2022-09-04 04:54:08] USER2 WITHDRAWs 2773.41 from DAI proceeds
# [2022-09-04 04:54:08] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-04 04:54:08] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-04 14:39:31] USER1 DEPOSITs 46.82 SYS
# [2022-09-04 14:39:31] USER1 SWAPs 34.60 SYS for DAI
# [2022-09-04 14:39:31] USER1 WITHDRAWs 34.60 from DAI proceeds
# [2022-09-04 14:39:31] USER1 WITHDRAWs 29.97 SYS
# [2022-09-04 14:39:31] USER1 DEPOSITs 29.97 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-05 14:39:31] USER1 DEPOSITs 53.46 SYS
# [2022-09-05 14:39:31] USER1 SWAPs 21.88 SYS for DAI
# [2022-09-05 14:39:31] USER1 WITHDRAWs 21.88 from DAI proceeds
# [2022-09-05 14:39:31] USER1 WITHDRAWs 17.60 SYS
# [2022-09-05 14:39:31] USER1 DEPOSITs 17.60 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-06 14:39:31] USER1 DEPOSITs 46.69 SYS
# [2022-09-06 14:39:31] USER1 SWAPs 21.26 SYS for DAI
# [2022-09-06 14:39:31] USER1 WITHDRAWs 21.26 from DAI proceeds
# [2022-09-06 14:39:31] USER1 WITHDRAWs 25.00 SYS
# [2022-09-06 14:39:31] USER1 DEPOSITs 25.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-07 02:28:16] USER2 DEPOSITs 5546.39 SYS
# [2022-09-07 02:28:16] USER2 SWAPs 2773.19 SYS for DAI
# [2022-09-07 02:28:16] USER2 WITHDRAWs 2773.19 from DAI proceeds
# [2022-09-07 02:28:16] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-07 02:28:16] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-07 14:39:31] USER1 DEPOSITs 47.50 SYS
# [2022-09-07 14:39:31] USER1 SWAPs 28.49 SYS for DAI
# [2022-09-07 14:39:31] USER1 WITHDRAWs 28.49 from DAI proceeds
# [2022-09-07 14:39:31] USER1 WITHDRAWs 27.60 SYS
# [2022-09-07 14:39:31] USER1 DEPOSITs 27.60 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-08 14:39:31] USER1 DEPOSITs 46.44 SYS
# [2022-09-08 14:39:31] USER1 SWAPs 25.74 SYS for DAI
# [2022-09-08 14:39:31] USER1 WITHDRAWs 25.74 from DAI proceeds
# [2022-09-08 14:39:31] USER1 WITHDRAWs 22.90 SYS
# [2022-09-08 14:39:31] USER1 DEPOSITs 22.90 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-09 14:39:31] USER1 DEPOSITs 55.65 SYS
# [2022-09-09 14:39:31] USER1 SWAPs 23.35 SYS for DAI
# [2022-09-09 14:39:31] USER1 WITHDRAWs 23.35 from DAI proceeds
# [2022-09-09 14:39:31] USER1 WITHDRAWs 15.96 SYS
# [2022-09-09 14:39:31] USER1 DEPOSITs 15.96 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-10 00:50:11] USER2 DEPOSITs 5545.96 SYS
# [2022-09-10 00:50:11] USER2 SWAPs 2772.98 SYS for DAI
# [2022-09-10 00:50:11] USER2 WITHDRAWs 2772.98 from DAI proceeds
# [2022-09-10 00:50:11] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-10 00:50:11] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-10 14:39:31] USER1 DEPOSITs 54.16 SYS
# [2022-09-10 14:39:31] USER1 SWAPs 24.65 SYS for DAI
# [2022-09-10 14:39:31] USER1 WITHDRAWs 24.65 from DAI proceeds
# [2022-09-10 14:39:31] USER1 WITHDRAWs 30.52 SYS
# [2022-09-10 14:39:31] USER1 DEPOSITs 30.52 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-10 15:00:47] USER2 DEPOSITs 5545.53 SYS
# [2022-09-10 15:00:47] USER2 SWAPs 2772.77 SYS for DAI
# [2022-09-10 15:00:47] USER2 WITHDRAWs 2772.77 from DAI proceeds
# [2022-09-10 15:00:47] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-10 15:00:47] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-11 14:39:31] USER1 DEPOSITs 47.99 SYS
# [2022-09-11 14:39:31] USER1 SWAPs 32.09 SYS for DAI
# [2022-09-11 14:39:31] USER1 WITHDRAWs 32.09 from DAI proceeds
# [2022-09-11 14:39:31] USER1 WITHDRAWs 29.07 SYS
# [2022-09-11 14:39:31] USER1 DEPOSITs 29.07 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-11 20:19:02] USER2 DEPOSITs 5545.11 SYS
# [2022-09-11 20:19:02] USER2 SWAPs 2772.55 SYS for DAI
# [2022-09-11 20:19:02] USER2 WITHDRAWs 2772.55 from DAI proceeds
# [2022-09-11 20:19:02] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-11 20:19:02] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-12 14:39:31] USER1 DEPOSITs 59.49 SYS
# [2022-09-12 14:39:31] USER1 SWAPs 23.80 SYS for DAI
# [2022-09-12 14:39:31] USER1 WITHDRAWs 23.80 from DAI proceeds
# [2022-09-12 14:39:31] USER1 WITHDRAWs 28.71 SYS
# [2022-09-12 14:39:31] USER1 DEPOSITs 28.71 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-13 14:00:13] USER2 DEPOSITs 5544.68 SYS
# [2022-09-13 14:00:13] USER2 SWAPs 2772.34 SYS for DAI
# [2022-09-13 14:00:13] USER2 WITHDRAWs 2772.34 from DAI proceeds
# [2022-09-13 14:00:13] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-13 14:00:13] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-13 14:39:31] USER1 DEPOSITs 43.12 SYS
# [2022-09-13 14:39:31] USER1 SWAPs 24.36 SYS for DAI
# [2022-09-13 14:39:31] USER1 WITHDRAWs 24.36 from DAI proceeds
# [2022-09-13 14:39:31] USER1 WITHDRAWs 12.60 SYS
# [2022-09-13 14:39:31] USER1 DEPOSITs 12.60 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-14 11:00:07] USER2 DEPOSITs 5544.25 SYS
# [2022-09-14 11:00:07] USER2 SWAPs 2772.13 SYS for DAI
# [2022-09-14 11:00:07] USER2 WITHDRAWs 2772.13 from DAI proceeds
# [2022-09-14 11:00:07] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-14 11:00:07] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-14 13:35:43] USER2 DEPOSITs 5543.83 SYS
# [2022-09-14 13:35:43] USER2 SWAPs 2771.91 SYS for DAI
# [2022-09-14 13:35:43] USER2 WITHDRAWs 2771.91 from DAI proceeds
# [2022-09-14 13:35:43] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-14 13:35:43] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-14 14:39:31] USER1 DEPOSITs 56.54 SYS
# [2022-09-14 14:39:31] USER1 SWAPs 23.46 SYS for DAI
# [2022-09-14 14:39:31] USER1 WITHDRAWs 23.46 from DAI proceeds
# [2022-09-14 14:39:31] USER1 WITHDRAWs 28.33 SYS
# [2022-09-14 14:39:31] USER1 DEPOSITs 28.33 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-15 14:39:31] USER1 DEPOSITs 60.17 SYS
# [2022-09-15 14:39:31] USER1 SWAPs 36.30 SYS for DAI
# [2022-09-15 14:39:31] USER1 WITHDRAWs 36.30 from DAI proceeds
# [2022-09-15 14:39:31] USER1 WITHDRAWs 29.01 SYS
# [2022-09-15 14:39:31] USER1 DEPOSITs 29.01 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-16 14:39:31] USER1 DEPOSITs 43.07 SYS
# [2022-09-16 14:39:31] USER1 SWAPs 33.63 SYS for DAI
# [2022-09-16 14:39:31] USER1 WITHDRAWs 33.63 from DAI proceeds
# [2022-09-16 14:39:31] USER1 WITHDRAWs 25.31 SYS
# [2022-09-16 14:39:31] USER1 DEPOSITs 25.31 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-17 14:39:31] USER1 DEPOSITs 45.61 SYS
# [2022-09-17 14:39:31] USER1 SWAPs 26.11 SYS for DAI
# [2022-09-17 14:39:31] USER1 WITHDRAWs 26.11 from DAI proceeds
# [2022-09-17 14:39:31] USER1 WITHDRAWs 25.56 SYS
# [2022-09-17 14:39:31] USER1 DEPOSITs 25.56 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-17 18:42:26] USER2 DEPOSITs 5543.40 SYS
# [2022-09-17 18:42:26] USER2 SWAPs 2771.70 SYS for DAI
# [2022-09-17 18:42:26] USER2 WITHDRAWs 2771.70 from DAI proceeds
# [2022-09-17 18:42:26] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-17 18:42:26] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-18 14:39:31] USER1 DEPOSITs 51.37 SYS
# [2022-09-18 14:39:31] USER1 SWAPs 23.63 SYS for DAI
# [2022-09-18 14:39:31] USER1 WITHDRAWs 23.63 from DAI proceeds
# [2022-09-18 14:39:31] USER1 WITHDRAWs 21.49 SYS
# [2022-09-18 14:39:31] USER1 DEPOSITs 21.49 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-19 14:39:31] USER1 DEPOSITs 49.12 SYS
# [2022-09-19 14:39:31] USER1 SWAPs 18.53 SYS for DAI
# [2022-09-19 14:39:31] USER1 WITHDRAWs 18.53 from DAI proceeds
# [2022-09-19 14:39:31] USER1 WITHDRAWs 28.24 SYS
# [2022-09-19 14:39:31] USER1 DEPOSITs 28.24 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-20 14:39:31] USER1 DEPOSITs 49.61 SYS
# [2022-09-20 14:39:31] USER1 SWAPs 18.66 SYS for DAI
# [2022-09-20 14:39:31] USER1 WITHDRAWs 18.66 from DAI proceeds
# [2022-09-20 14:39:31] USER1 WITHDRAWs 28.34 SYS
# [2022-09-20 14:39:31] USER1 DEPOSITs 28.34 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-21 05:24:09] USER2 DEPOSITs 5542.97 SYS
# [2022-09-21 05:24:09] USER2 SWAPs 2771.49 SYS for DAI
# [2022-09-21 05:24:09] USER2 WITHDRAWs 2771.49 from DAI proceeds
# [2022-09-21 05:24:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-21 05:24:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-21 14:39:31] USER1 DEPOSITs 49.67 SYS
# [2022-09-21 14:39:31] USER1 SWAPs 26.09 SYS for DAI
# [2022-09-21 14:39:31] USER1 WITHDRAWs 26.09 from DAI proceeds
# [2022-09-21 14:39:31] USER1 WITHDRAWs 25.88 SYS
# [2022-09-21 14:39:31] USER1 DEPOSITs 25.88 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-22 14:39:31] USER1 DEPOSITs 53.80 SYS
# [2022-09-22 14:39:31] USER1 SWAPs 29.73 SYS for DAI
# [2022-09-22 14:39:31] USER1 WITHDRAWs 29.73 from DAI proceeds
# [2022-09-22 14:39:31] USER1 WITHDRAWs 35.33 SYS
# [2022-09-22 14:39:31] USER1 DEPOSITs 35.33 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-23 04:18:03] USER2 DEPOSITs 5542.54 SYS
# [2022-09-23 04:18:03] USER2 SWAPs 2771.27 SYS for DAI
# [2022-09-23 04:18:03] USER2 WITHDRAWs 2771.27 from DAI proceeds
# [2022-09-23 04:18:03] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-23 04:18:03] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-23 11:21:08] USER2 DEPOSITs 5542.12 SYS
# [2022-09-23 11:21:08] USER2 SWAPs 2771.06 SYS for DAI
# [2022-09-23 11:21:08] USER2 WITHDRAWs 2771.06 from DAI proceeds
# [2022-09-23 11:21:08] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-23 11:21:08] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-23 14:39:31] USER1 DEPOSITs 46.43 SYS
# [2022-09-23 14:39:31] USER1 SWAPs 27.36 SYS for DAI
# [2022-09-23 14:39:31] USER1 WITHDRAWs 27.36 from DAI proceeds
# [2022-09-23 14:39:31] USER1 WITHDRAWs 24.70 SYS
# [2022-09-23 14:39:31] USER1 DEPOSITs 24.70 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-23 20:45:53] USER2 DEPOSITs 5541.69 SYS
# [2022-09-23 20:45:53] USER2 SWAPs 2770.85 SYS for DAI
# [2022-09-23 20:45:53] USER2 WITHDRAWs 2770.85 from DAI proceeds
# [2022-09-23 20:45:53] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-23 20:45:53] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-23 23:16:10] USER2 DEPOSITs 5541.26 SYS
# [2022-09-23 23:16:10] USER2 SWAPs 2770.63 SYS for DAI
# [2022-09-23 23:16:10] USER2 WITHDRAWs 2770.63 from DAI proceeds
# [2022-09-23 23:16:10] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-23 23:16:10] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-24 14:39:31] USER1 DEPOSITs 55.34 SYS
# [2022-09-24 14:39:31] USER1 SWAPs 21.99 SYS for DAI
# [2022-09-24 14:39:31] USER1 WITHDRAWs 21.99 from DAI proceeds
# [2022-09-24 14:39:31] USER1 WITHDRAWs 19.70 SYS
# [2022-09-24 14:39:31] USER1 DEPOSITs 19.70 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-25 13:35:15] USER2 DEPOSITs 5540.84 SYS
# [2022-09-25 13:35:15] USER2 SWAPs 2770.42 SYS for DAI
# [2022-09-25 13:35:15] USER2 WITHDRAWs 2770.42 from DAI proceeds
# [2022-09-25 13:35:15] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-25 13:35:15] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-25 14:39:31] USER1 DEPOSITs 47.85 SYS
# [2022-09-25 14:39:31] USER1 SWAPs 22.42 SYS for DAI
# [2022-09-25 14:39:31] USER1 WITHDRAWs 22.42 from DAI proceeds
# [2022-09-25 14:39:31] USER1 WITHDRAWs 26.93 SYS
# [2022-09-25 14:39:31] USER1 DEPOSITs 26.93 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-26 14:39:31] USER1 DEPOSITs 57.17 SYS
# [2022-09-26 14:39:31] USER1 SWAPs 19.58 SYS for DAI
# [2022-09-26 14:39:31] USER1 WITHDRAWs 19.58 from DAI proceeds
# [2022-09-26 14:39:31] USER1 WITHDRAWs 18.46 SYS
# [2022-09-26 14:39:31] USER1 DEPOSITs 18.46 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-27 14:39:31] USER1 DEPOSITs 46.92 SYS
# [2022-09-27 14:39:31] USER1 SWAPs 27.45 SYS for DAI
# [2022-09-27 14:39:31] USER1 WITHDRAWs 27.45 from DAI proceeds
# [2022-09-27 14:39:31] USER1 WITHDRAWs 26.68 SYS
# [2022-09-27 14:39:31] USER1 DEPOSITs 26.68 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-28 14:39:31] USER1 DEPOSITs 49.02 SYS
# [2022-09-28 14:39:31] USER1 SWAPs 25.69 SYS for DAI
# [2022-09-28 14:39:31] USER1 WITHDRAWs 25.69 from DAI proceeds
# [2022-09-28 14:39:31] USER1 WITHDRAWs 31.59 SYS
# [2022-09-28 14:39:31] USER1 DEPOSITs 31.59 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-29 14:39:31] USER1 DEPOSITs 37.92 SYS
# [2022-09-29 14:39:31] USER1 SWAPs 31.67 SYS for DAI
# [2022-09-29 14:39:31] USER1 WITHDRAWs 31.67 from DAI proceeds
# [2022-09-29 14:39:31] USER1 WITHDRAWs 18.98 SYS
# [2022-09-29 14:39:31] USER1 DEPOSITs 18.98 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-30 06:01:37] USER2 DEPOSITs 5540.41 SYS
# [2022-09-30 06:01:37] USER2 SWAPs 2770.21 SYS for DAI
# [2022-09-30 06:01:37] USER2 WITHDRAWs 2770.21 from DAI proceeds
# [2022-09-30 06:01:37] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-30 06:01:37] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-30 14:39:31] USER1 DEPOSITs 48.34 SYS
# [2022-09-30 14:39:31] USER1 SWAPs 20.90 SYS for DAI
# [2022-09-30 14:39:31] USER1 WITHDRAWs 20.90 from DAI proceeds
# [2022-09-30 14:39:31] USER1 WITHDRAWs 31.80 SYS
# [2022-09-30 14:39:31] USER1 DEPOSITs 31.80 SYS_DAI_LP from SYS and DAI proceeds
# [2022-09-30 15:49:22] USER2 DEPOSITs 5539.99 SYS
# [2022-09-30 15:49:22] USER2 SWAPs 2769.99 SYS for DAI
# [2022-09-30 15:49:22] USER2 WITHDRAWs 2769.99 from DAI proceeds
# [2022-09-30 15:49:22] USER2 WITHDRAWs 2500.00 SYS
# [2022-09-30 15:49:22] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-01 02:33:01] USER2 DEPOSITs 5539.56 SYS
# [2022-10-01 02:33:01] USER2 SWAPs 2769.78 SYS for DAI
# [2022-10-01 02:33:01] USER2 WITHDRAWs 2769.78 from DAI proceeds
# [2022-10-01 02:33:01] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-01 02:33:01] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-01 14:39:31] USER1 DEPOSITs 45.11 SYS
# [2022-10-01 14:39:31] USER1 SWAPs 32.32 SYS for DAI
# [2022-10-01 14:39:31] USER1 WITHDRAWs 32.32 from DAI proceeds
# [2022-10-01 14:39:31] USER1 WITHDRAWs 25.74 SYS
# [2022-10-01 14:39:31] USER1 DEPOSITs 25.74 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-02 14:39:31] USER1 DEPOSITs 50.92 SYS
# [2022-10-02 14:39:31] USER1 SWAPs 22.14 SYS for DAI
# [2022-10-02 14:39:31] USER1 WITHDRAWs 22.14 from DAI proceeds
# [2022-10-02 14:39:31] USER1 WITHDRAWs 25.52 SYS
# [2022-10-02 14:39:31] USER1 DEPOSITs 25.52 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-03 13:58:07] USER2 DEPOSITs 5539.13 SYS
# [2022-10-03 13:58:07] USER2 SWAPs 2769.57 SYS for DAI
# [2022-10-03 13:58:07] USER2 WITHDRAWs 2769.57 from DAI proceeds
# [2022-10-03 13:58:07] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-03 13:58:07] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-03 14:39:31] USER1 DEPOSITs 53.20 SYS
# [2022-10-03 14:39:31] USER1 SWAPs 26.79 SYS for DAI
# [2022-10-03 14:39:31] USER1 WITHDRAWs 26.79 from DAI proceeds
# [2022-10-03 14:39:31] USER1 WITHDRAWs 18.32 SYS
# [2022-10-03 14:39:31] USER1 DEPOSITs 18.32 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-03 15:53:50] USER2 DEPOSITs 5538.71 SYS
# [2022-10-03 15:53:50] USER2 SWAPs 2769.35 SYS for DAI
# [2022-10-03 15:53:50] USER2 WITHDRAWs 2769.35 from DAI proceeds
# [2022-10-03 15:53:50] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-03 15:53:50] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-03 17:28:41] USER2 DEPOSITs 5538.28 SYS
# [2022-10-03 17:28:41] USER2 SWAPs 2769.14 SYS for DAI
# [2022-10-03 17:28:41] USER2 WITHDRAWs 2769.14 from DAI proceeds
# [2022-10-03 17:28:41] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-03 17:28:41] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-04 14:39:31] USER1 DEPOSITs 48.49 SYS
# [2022-10-04 14:39:31] USER1 SWAPs 28.35 SYS for DAI
# [2022-10-04 14:39:31] USER1 WITHDRAWs 28.35 from DAI proceeds
# [2022-10-04 14:39:31] USER1 WITHDRAWs 25.12 SYS
# [2022-10-04 14:39:31] USER1 DEPOSITs 25.12 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-04 20:46:54] USER2 DEPOSITs 5537.85 SYS
# [2022-10-04 20:46:54] USER2 SWAPs 2768.93 SYS for DAI
# [2022-10-04 20:46:54] USER2 WITHDRAWs 2768.93 from DAI proceeds
# [2022-10-04 20:46:54] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-04 20:46:54] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-05 14:39:31] USER1 DEPOSITs 40.47 SYS
# [2022-10-05 14:39:31] USER1 SWAPs 25.75 SYS for DAI
# [2022-10-05 14:39:31] USER1 WITHDRAWs 25.75 from DAI proceeds
# [2022-10-05 14:39:31] USER1 WITHDRAWs 19.84 SYS
# [2022-10-05 14:39:31] USER1 DEPOSITs 19.84 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-06 14:39:31] USER1 DEPOSITs 49.15 SYS
# [2022-10-06 14:39:31] USER1 SWAPs 27.01 SYS for DAI
# [2022-10-06 14:39:31] USER1 WITHDRAWs 27.01 from DAI proceeds
# [2022-10-06 14:39:31] USER1 WITHDRAWs 19.40 SYS
# [2022-10-06 14:39:31] USER1 DEPOSITs 19.40 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-06 19:43:42] USER2 DEPOSITs 5537.43 SYS
# [2022-10-06 19:43:42] USER2 SWAPs 2768.71 SYS for DAI
# [2022-10-06 19:43:42] USER2 WITHDRAWs 2768.71 from DAI proceeds
# [2022-10-06 19:43:42] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-06 19:43:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-07 12:23:04] USER2 DEPOSITs 5537.00 SYS
# [2022-10-07 12:23:04] USER2 SWAPs 2768.50 SYS for DAI
# [2022-10-07 12:23:04] USER2 WITHDRAWs 2768.50 from DAI proceeds
# [2022-10-07 12:23:04] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-07 12:23:04] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-07 14:02:44] USER2 DEPOSITs 5536.58 SYS
# [2022-10-07 14:02:44] USER2 SWAPs 2768.29 SYS for DAI
# [2022-10-07 14:02:44] USER2 WITHDRAWs 2768.29 from DAI proceeds
# [2022-10-07 14:02:44] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-07 14:02:44] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-07 14:39:31] USER1 DEPOSITs 55.79 SYS
# [2022-10-07 14:39:31] USER1 SWAPs 22.52 SYS for DAI
# [2022-10-07 14:39:31] USER1 WITHDRAWs 22.52 from DAI proceeds
# [2022-10-07 14:39:31] USER1 WITHDRAWs 23.23 SYS
# [2022-10-07 14:39:31] USER1 DEPOSITs 23.23 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-07 20:12:31] USER2 DEPOSITs 5536.15 SYS
# [2022-10-07 20:12:31] USER2 SWAPs 2768.08 SYS for DAI
# [2022-10-07 20:12:31] USER2 WITHDRAWs 2768.08 from DAI proceeds
# [2022-10-07 20:12:31] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-07 20:12:31] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-08 05:05:41] USER2 DEPOSITs 5535.72 SYS
# [2022-10-08 05:05:41] USER2 SWAPs 2767.86 SYS for DAI
# [2022-10-08 05:05:41] USER2 WITHDRAWs 2767.86 from DAI proceeds
# [2022-10-08 05:05:41] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-08 05:05:41] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-08 07:46:58] USER2 DEPOSITs 5535.30 SYS
# [2022-10-08 07:46:58] USER2 SWAPs 2767.65 SYS for DAI
# [2022-10-08 07:46:58] USER2 WITHDRAWs 2767.65 from DAI proceeds
# [2022-10-08 07:46:58] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-08 07:46:58] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-08 14:39:31] USER1 DEPOSITs 50.91 SYS
# [2022-10-08 14:39:31] USER1 SWAPs 22.05 SYS for DAI
# [2022-10-08 14:39:31] USER1 WITHDRAWs 22.05 from DAI proceeds
# [2022-10-08 14:39:31] USER1 WITHDRAWs 31.21 SYS
# [2022-10-08 14:39:31] USER1 DEPOSITs 31.21 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-09 10:40:42] USER2 DEPOSITs 5534.87 SYS
# [2022-10-09 10:40:42] USER2 SWAPs 2767.44 SYS for DAI
# [2022-10-09 10:40:42] USER2 WITHDRAWs 2767.44 from DAI proceeds
# [2022-10-09 10:40:42] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-09 10:40:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-09 14:39:31] USER1 DEPOSITs 55.13 SYS
# [2022-10-09 14:39:31] USER1 SWAPs 28.43 SYS for DAI
# [2022-10-09 14:39:31] USER1 WITHDRAWs 28.43 from DAI proceeds
# [2022-10-09 14:39:31] USER1 WITHDRAWs 19.49 SYS
# [2022-10-09 14:39:31] USER1 DEPOSITs 19.49 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-10 14:39:31] USER1 DEPOSITs 59.23 SYS
# [2022-10-10 14:39:31] USER1 SWAPs 28.03 SYS for DAI
# [2022-10-10 14:39:31] USER1 WITHDRAWs 28.03 from DAI proceeds
# [2022-10-10 14:39:31] USER1 WITHDRAWs 20.48 SYS
# [2022-10-10 14:39:31] USER1 DEPOSITs 20.48 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-10 18:15:46] USER2 DEPOSITs 5534.45 SYS
# [2022-10-10 18:15:46] USER2 SWAPs 2767.22 SYS for DAI
# [2022-10-10 18:15:46] USER2 WITHDRAWs 2767.22 from DAI proceeds
# [2022-10-10 18:15:46] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-10 18:15:46] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-10 22:48:35] USER2 DEPOSITs 5534.02 SYS
# [2022-10-10 22:48:35] USER2 SWAPs 2767.01 SYS for DAI
# [2022-10-10 22:48:35] USER2 WITHDRAWs 2767.01 from DAI proceeds
# [2022-10-10 22:48:35] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-10 22:48:35] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-11 14:39:31] USER1 DEPOSITs 45.68 SYS
# [2022-10-11 14:39:31] USER1 SWAPs 25.44 SYS for DAI
# [2022-10-11 14:39:31] USER1 WITHDRAWs 25.44 from DAI proceeds
# [2022-10-11 14:39:31] USER1 WITHDRAWs 17.48 SYS
# [2022-10-11 14:39:31] USER1 DEPOSITs 17.48 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-12 14:39:31] USER1 DEPOSITs 49.03 SYS
# [2022-10-12 14:39:31] USER1 SWAPs 18.19 SYS for DAI
# [2022-10-12 14:39:31] USER1 WITHDRAWs 18.19 from DAI proceeds
# [2022-10-12 14:39:31] USER1 WITHDRAWs 25.82 SYS
# [2022-10-12 14:39:31] USER1 DEPOSITs 25.82 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-13 08:15:12] USER2 DEPOSITs 5533.60 SYS
# [2022-10-13 08:15:12] USER2 SWAPs 2766.80 SYS for DAI
# [2022-10-13 08:15:12] USER2 WITHDRAWs 2766.80 from DAI proceeds
# [2022-10-13 08:15:12] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-13 08:15:12] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-13 14:16:30] USER2 DEPOSITs 5533.17 SYS
# [2022-10-13 14:16:30] USER2 SWAPs 2766.59 SYS for DAI
# [2022-10-13 14:16:30] USER2 WITHDRAWs 2766.59 from DAI proceeds
# [2022-10-13 14:16:30] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-13 14:16:30] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-13 14:39:31] USER1 DEPOSITs 53.49 SYS
# [2022-10-13 14:39:31] USER1 SWAPs 28.80 SYS for DAI
# [2022-10-13 14:39:31] USER1 WITHDRAWs 28.80 from DAI proceeds
# [2022-10-13 14:39:31] USER1 WITHDRAWs 15.65 SYS
# [2022-10-13 14:39:31] USER1 DEPOSITs 15.65 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-13 20:17:19] USER2 DEPOSITs 5532.75 SYS
# [2022-10-13 20:17:19] USER2 SWAPs 2766.37 SYS for DAI
# [2022-10-13 20:17:19] USER2 WITHDRAWs 2766.37 from DAI proceeds
# [2022-10-13 20:17:19] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-13 20:17:19] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-14 14:39:31] USER1 DEPOSITs 41.55 SYS
# [2022-10-14 14:39:31] USER1 SWAPs 32.24 SYS for DAI
# [2022-10-14 14:39:31] USER1 WITHDRAWs 32.24 from DAI proceeds
# [2022-10-14 14:39:31] USER1 WITHDRAWs 24.38 SYS
# [2022-10-14 14:39:31] USER1 DEPOSITs 24.38 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-14 14:48:59] USER2 DEPOSITs 5532.32 SYS
# [2022-10-14 14:48:59] USER2 SWAPs 2766.16 SYS for DAI
# [2022-10-14 14:48:59] USER2 WITHDRAWs 2766.16 from DAI proceeds
# [2022-10-14 14:48:59] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-14 14:48:59] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-15 14:39:31] USER1 DEPOSITs 39.14 SYS
# [2022-10-15 14:39:31] USER1 SWAPs 24.92 SYS for DAI
# [2022-10-15 14:39:31] USER1 WITHDRAWs 24.92 from DAI proceeds
# [2022-10-15 14:39:31] USER1 WITHDRAWs 20.33 SYS
# [2022-10-15 14:39:31] USER1 DEPOSITs 20.33 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-16 14:39:31] USER1 DEPOSITs 47.16 SYS
# [2022-10-16 14:39:31] USER1 SWAPs 30.60 SYS for DAI
# [2022-10-16 14:39:31] USER1 WITHDRAWs 30.60 from DAI proceeds
# [2022-10-16 14:39:31] USER1 WITHDRAWs 22.43 SYS
# [2022-10-16 14:39:31] USER1 DEPOSITs 22.43 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-16 17:47:09] USER2 DEPOSITs 5531.90 SYS
# [2022-10-16 17:47:09] USER2 SWAPs 2765.95 SYS for DAI
# [2022-10-16 17:47:09] USER2 WITHDRAWs 2765.95 from DAI proceeds
# [2022-10-16 17:47:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-16 17:47:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-17 14:39:31] USER1 DEPOSITs 53.93 SYS
# [2022-10-17 14:39:31] USER1 SWAPs 29.68 SYS for DAI
# [2022-10-17 14:39:31] USER1 WITHDRAWs 29.68 from DAI proceeds
# [2022-10-17 14:39:31] USER1 WITHDRAWs 27.82 SYS
# [2022-10-17 14:39:31] USER1 DEPOSITs 27.82 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-17 19:24:22] USER2 DEPOSITs 5531.47 SYS
# [2022-10-17 19:24:22] USER2 SWAPs 2765.74 SYS for DAI
# [2022-10-17 19:24:22] USER2 WITHDRAWs 2765.74 from DAI proceeds
# [2022-10-17 19:24:22] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-17 19:24:22] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-18 14:39:31] USER1 DEPOSITs 56.08 SYS
# [2022-10-18 14:39:31] USER1 SWAPs 27.66 SYS for DAI
# [2022-10-18 14:39:31] USER1 WITHDRAWs 27.66 from DAI proceeds
# [2022-10-18 14:39:31] USER1 WITHDRAWs 16.29 SYS
# [2022-10-18 14:39:31] USER1 DEPOSITs 16.29 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-19 05:00:53] USER2 DEPOSITs 5531.05 SYS
# [2022-10-19 05:00:53] USER2 SWAPs 2765.52 SYS for DAI
# [2022-10-19 05:00:53] USER2 WITHDRAWs 2765.52 from DAI proceeds
# [2022-10-19 05:00:53] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-19 05:00:53] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-19 14:39:31] USER1 DEPOSITs 53.77 SYS
# [2022-10-19 14:39:31] USER1 SWAPs 20.46 SYS for DAI
# [2022-10-19 14:39:31] USER1 WITHDRAWs 20.46 from DAI proceeds
# [2022-10-19 14:39:31] USER1 WITHDRAWs 23.21 SYS
# [2022-10-19 14:39:31] USER1 DEPOSITs 23.21 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-20 12:44:12] USER2 DEPOSITs 5530.62 SYS
# [2022-10-20 12:44:12] USER2 SWAPs 2765.31 SYS for DAI
# [2022-10-20 12:44:12] USER2 WITHDRAWs 2765.31 from DAI proceeds
# [2022-10-20 12:44:12] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-20 12:44:12] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-20 14:39:31] USER1 DEPOSITs 51.73 SYS
# [2022-10-20 14:39:31] USER1 SWAPs 22.75 SYS for DAI
# [2022-10-20 14:39:31] USER1 WITHDRAWs 22.75 from DAI proceeds
# [2022-10-20 14:39:31] USER1 WITHDRAWs 22.98 SYS
# [2022-10-20 14:39:31] USER1 DEPOSITs 22.98 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-21 08:26:42] USER2 DEPOSITs 5530.20 SYS
# [2022-10-21 08:26:42] USER2 SWAPs 2765.10 SYS for DAI
# [2022-10-21 08:26:42] USER2 WITHDRAWs 2765.10 from DAI proceeds
# [2022-10-21 08:26:42] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-21 08:26:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-21 14:39:31] USER1 DEPOSITs 44.97 SYS
# [2022-10-21 14:39:31] USER1 SWAPs 27.05 SYS for DAI
# [2022-10-21 14:39:31] USER1 WITHDRAWs 27.05 from DAI proceeds
# [2022-10-21 14:39:31] USER1 WITHDRAWs 17.72 SYS
# [2022-10-21 14:39:31] USER1 DEPOSITs 17.72 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-21 14:58:55] USER2 DEPOSITs 5529.77 SYS
# [2022-10-21 14:58:55] USER2 SWAPs 2764.89 SYS for DAI
# [2022-10-21 14:58:55] USER2 WITHDRAWs 2764.89 from DAI proceeds
# [2022-10-21 14:58:55] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-21 14:58:55] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-21 21:10:37] USER2 DEPOSITs 5529.35 SYS
# [2022-10-21 21:10:37] USER2 SWAPs 2764.67 SYS for DAI
# [2022-10-21 21:10:37] USER2 WITHDRAWs 2764.67 from DAI proceeds
# [2022-10-21 21:10:37] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-21 21:10:37] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-22 14:39:31] USER1 DEPOSITs 47.23 SYS
# [2022-10-22 14:39:31] USER1 SWAPs 31.06 SYS for DAI
# [2022-10-22 14:39:31] USER1 WITHDRAWs 31.06 from DAI proceeds
# [2022-10-22 14:39:31] USER1 WITHDRAWs 26.74 SYS
# [2022-10-22 14:39:31] USER1 DEPOSITs 26.74 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-22 19:40:41] USER2 DEPOSITs 5528.92 SYS
# [2022-10-22 19:40:41] USER2 SWAPs 2764.46 SYS for DAI
# [2022-10-22 19:40:41] USER2 WITHDRAWs 2764.46 from DAI proceeds
# [2022-10-22 19:40:41] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-22 19:40:41] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-22 21:19:52] USER2 DEPOSITs 5528.50 SYS
# [2022-10-22 21:19:52] USER2 SWAPs 2764.25 SYS for DAI
# [2022-10-22 21:19:52] USER2 WITHDRAWs 2764.25 from DAI proceeds
# [2022-10-22 21:19:52] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-22 21:19:52] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-23 14:39:31] USER1 DEPOSITs 49.31 SYS
# [2022-10-23 14:39:31] USER1 SWAPs 27.28 SYS for DAI
# [2022-10-23 14:39:31] USER1 WITHDRAWs 27.28 from DAI proceeds
# [2022-10-23 14:39:31] USER1 WITHDRAWs 22.45 SYS
# [2022-10-23 14:39:31] USER1 DEPOSITs 22.45 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-24 14:39:31] USER1 DEPOSITs 43.46 SYS
# [2022-10-24 14:39:31] USER1 SWAPs 23.37 SYS for DAI
# [2022-10-24 14:39:31] USER1 WITHDRAWs 23.37 from DAI proceeds
# [2022-10-24 14:39:31] USER1 WITHDRAWs 27.23 SYS
# [2022-10-24 14:39:31] USER1 DEPOSITs 27.23 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-24 20:39:33] USER2 DEPOSITs 5528.07 SYS
# [2022-10-24 20:39:33] USER2 SWAPs 2764.04 SYS for DAI
# [2022-10-24 20:39:33] USER2 WITHDRAWs 2764.04 from DAI proceeds
# [2022-10-24 20:39:33] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-24 20:39:33] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-25 14:39:31] USER1 DEPOSITs 47.49 SYS
# [2022-10-25 14:39:31] USER1 SWAPs 20.41 SYS for DAI
# [2022-10-25 14:39:31] USER1 WITHDRAWs 20.41 from DAI proceeds
# [2022-10-25 14:39:31] USER1 WITHDRAWs 22.29 SYS
# [2022-10-25 14:39:31] USER1 DEPOSITs 22.29 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-26 14:39:31] USER1 DEPOSITs 49.95 SYS
# [2022-10-26 14:39:31] USER1 SWAPs 29.20 SYS for DAI
# [2022-10-26 14:39:31] USER1 WITHDRAWs 29.20 from DAI proceeds
# [2022-10-26 14:39:31] USER1 WITHDRAWs 16.70 SYS
# [2022-10-26 14:39:31] USER1 DEPOSITs 16.70 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-27 14:39:31] USER1 DEPOSITs 57.16 SYS
# [2022-10-27 14:39:31] USER1 SWAPs 25.70 SYS for DAI
# [2022-10-27 14:39:31] USER1 WITHDRAWs 25.70 from DAI proceeds
# [2022-10-27 14:39:31] USER1 WITHDRAWs 27.40 SYS
# [2022-10-27 14:39:31] USER1 DEPOSITs 27.40 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-27 19:36:24] USER2 DEPOSITs 5527.65 SYS
# [2022-10-27 19:36:24] USER2 SWAPs 2763.82 SYS for DAI
# [2022-10-27 19:36:24] USER2 WITHDRAWs 2763.82 from DAI proceeds
# [2022-10-27 19:36:24] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-27 19:36:24] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-28 09:58:32] USER2 DEPOSITs 5527.22 SYS
# [2022-10-28 09:58:32] USER2 SWAPs 2763.61 SYS for DAI
# [2022-10-28 09:58:32] USER2 WITHDRAWs 2763.61 from DAI proceeds
# [2022-10-28 09:58:32] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-28 09:58:32] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-28 14:39:31] USER1 DEPOSITs 47.49 SYS
# [2022-10-28 14:39:31] USER1 SWAPs 23.21 SYS for DAI
# [2022-10-28 14:39:31] USER1 WITHDRAWs 23.21 from DAI proceeds
# [2022-10-28 14:39:31] USER1 WITHDRAWs 31.74 SYS
# [2022-10-28 14:39:31] USER1 DEPOSITs 31.74 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-29 14:19:48] USER2 DEPOSITs 5526.80 SYS
# [2022-10-29 14:19:48] USER2 SWAPs 2763.40 SYS for DAI
# [2022-10-29 14:19:48] USER2 WITHDRAWs 2763.40 from DAI proceeds
# [2022-10-29 14:19:48] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-29 14:19:48] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-29 14:39:31] USER1 DEPOSITs 40.94 SYS
# [2022-10-29 14:39:31] USER1 SWAPs 36.15 SYS for DAI
# [2022-10-29 14:39:31] USER1 WITHDRAWs 36.15 from DAI proceeds
# [2022-10-29 14:39:31] USER1 WITHDRAWs 25.35 SYS
# [2022-10-29 14:39:31] USER1 DEPOSITs 25.35 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-30 01:34:23] USER2 DEPOSITs 5526.37 SYS
# [2022-10-30 01:34:23] USER2 SWAPs 2763.19 SYS for DAI
# [2022-10-30 01:34:23] USER2 WITHDRAWs 2763.19 from DAI proceeds
# [2022-10-30 01:34:23] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-30 01:34:23] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-30 14:39:31] USER1 DEPOSITs 43.85 SYS
# [2022-10-30 14:39:31] USER1 SWAPs 33.37 SYS for DAI
# [2022-10-30 14:39:31] USER1 WITHDRAWs 33.37 from DAI proceeds
# [2022-10-30 14:39:31] USER1 WITHDRAWs 23.34 SYS
# [2022-10-30 14:39:31] USER1 DEPOSITs 23.34 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-31 14:39:31] USER1 DEPOSITs 43.96 SYS
# [2022-10-31 14:39:31] USER1 SWAPs 24.01 SYS for DAI
# [2022-10-31 14:39:31] USER1 WITHDRAWs 24.01 from DAI proceeds
# [2022-10-31 14:39:31] USER1 WITHDRAWs 26.84 SYS
# [2022-10-31 14:39:31] USER1 DEPOSITs 26.84 SYS_DAI_LP from SYS and DAI proceeds
# [2022-10-31 18:00:30] USER2 DEPOSITs 5525.95 SYS
# [2022-10-31 18:00:30] USER2 SWAPs 2762.98 SYS for DAI
# [2022-10-31 18:00:30] USER2 WITHDRAWs 2762.98 from DAI proceeds
# [2022-10-31 18:00:30] USER2 WITHDRAWs 2500.00 SYS
# [2022-10-31 18:00:30] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-01 01:06:15] USER2 DEPOSITs 5525.53 SYS
# [2022-11-01 01:06:15] USER2 SWAPs 2762.76 SYS for DAI
# [2022-11-01 01:06:15] USER2 WITHDRAWs 2762.76 from DAI proceeds
# [2022-11-01 01:06:15] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-01 01:06:15] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-01 10:48:28] USER2 DEPOSITs 5525.10 SYS
# [2022-11-01 10:48:28] USER2 SWAPs 2762.55 SYS for DAI
# [2022-11-01 10:48:28] USER2 WITHDRAWs 2762.55 from DAI proceeds
# [2022-11-01 10:48:28] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-01 10:48:28] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-01 14:39:31] USER1 DEPOSITs 52.64 SYS
# [2022-11-01 14:39:31] USER1 SWAPs 16.53 SYS for DAI
# [2022-11-01 14:39:31] USER1 WITHDRAWs 16.53 from DAI proceeds
# [2022-11-01 14:39:31] USER1 WITHDRAWs 30.27 SYS
# [2022-11-01 14:39:31] USER1 DEPOSITs 30.27 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-02 14:39:31] USER1 DEPOSITs 54.78 SYS
# [2022-11-02 14:39:31] USER1 SWAPs 23.54 SYS for DAI
# [2022-11-02 14:39:31] USER1 WITHDRAWs 23.54 from DAI proceeds
# [2022-11-02 14:39:31] USER1 WITHDRAWs 22.52 SYS
# [2022-11-02 14:39:31] USER1 DEPOSITs 22.52 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-03 14:39:31] USER1 DEPOSITs 56.53 SYS
# [2022-11-03 14:39:31] USER1 SWAPs 20.49 SYS for DAI
# [2022-11-03 14:39:31] USER1 WITHDRAWs 20.49 from DAI proceeds
# [2022-11-03 14:39:31] USER1 WITHDRAWs 25.84 SYS
# [2022-11-03 14:39:31] USER1 DEPOSITs 25.84 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-03 17:20:30] USER2 DEPOSITs 5524.68 SYS
# [2022-11-03 17:20:30] USER2 SWAPs 2762.34 SYS for DAI
# [2022-11-03 17:20:30] USER2 WITHDRAWs 2762.34 from DAI proceeds
# [2022-11-03 17:20:30] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-03 17:20:30] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-04 00:17:30] USER2 DEPOSITs 5524.25 SYS
# [2022-11-04 00:17:30] USER2 SWAPs 2762.13 SYS for DAI
# [2022-11-04 00:17:30] USER2 WITHDRAWs 2762.13 from DAI proceeds
# [2022-11-04 00:17:30] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-04 00:17:30] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-04 12:36:00] USER2 DEPOSITs 5523.83 SYS
# [2022-11-04 12:36:00] USER2 SWAPs 2761.91 SYS for DAI
# [2022-11-04 12:36:00] USER2 WITHDRAWs 2761.91 from DAI proceeds
# [2022-11-04 12:36:00] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-04 12:36:00] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-04 14:39:31] USER1 DEPOSITs 41.48 SYS
# [2022-11-04 14:39:31] USER1 SWAPs 25.88 SYS for DAI
# [2022-11-04 14:39:31] USER1 WITHDRAWs 25.88 from DAI proceeds
# [2022-11-04 14:39:31] USER1 WITHDRAWs 34.22 SYS
# [2022-11-04 14:39:31] USER1 DEPOSITs 34.22 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-05 14:39:31] USER1 DEPOSITs 53.46 SYS
# [2022-11-05 14:39:31] USER1 SWAPs 16.27 SYS for DAI
# [2022-11-05 14:39:31] USER1 WITHDRAWs 16.27 from DAI proceeds
# [2022-11-05 14:39:31] USER1 WITHDRAWs 21.67 SYS
# [2022-11-05 14:39:31] USER1 DEPOSITs 21.67 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-06 05:13:42] USER2 DEPOSITs 5523.41 SYS
# [2022-11-06 05:13:42] USER2 SWAPs 2761.70 SYS for DAI
# [2022-11-06 05:13:42] USER2 WITHDRAWs 2761.70 from DAI proceeds
# [2022-11-06 05:13:42] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-06 05:13:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-06 10:05:52] USER2 DEPOSITs 5522.98 SYS
# [2022-11-06 10:05:52] USER2 SWAPs 2761.49 SYS for DAI
# [2022-11-06 10:05:52] USER2 WITHDRAWs 2761.49 from DAI proceeds
# [2022-11-06 10:05:52] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-06 10:05:52] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-06 13:39:31] USER1 DEPOSITs 42.72 SYS
# [2022-11-06 13:39:31] USER1 SWAPs 26.97 SYS for DAI
# [2022-11-06 13:39:31] USER1 WITHDRAWs 26.97 from DAI proceeds
# [2022-11-06 13:39:31] USER1 WITHDRAWs 20.39 SYS
# [2022-11-06 13:39:31] USER1 DEPOSITs 20.39 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-07 13:39:31] USER1 DEPOSITs 56.12 SYS
# [2022-11-07 13:39:31] USER1 SWAPs 19.65 SYS for DAI
# [2022-11-07 13:39:31] USER1 WITHDRAWs 19.65 from DAI proceeds
# [2022-11-07 13:39:31] USER1 WITHDRAWs 24.23 SYS
# [2022-11-07 13:39:31] USER1 DEPOSITs 24.23 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-08 10:56:29] USER2 DEPOSITs 5522.56 SYS
# [2022-11-08 10:56:29] USER2 SWAPs 2761.28 SYS for DAI
# [2022-11-08 10:56:29] USER2 WITHDRAWs 2761.28 from DAI proceeds
# [2022-11-08 10:56:29] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-08 10:56:29] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-08 13:39:31] USER1 DEPOSITs 57.90 SYS
# [2022-11-08 13:39:31] USER1 SWAPs 23.51 SYS for DAI
# [2022-11-08 13:39:31] USER1 WITHDRAWs 23.51 from DAI proceeds
# [2022-11-08 13:39:31] USER1 WITHDRAWs 26.00 SYS
# [2022-11-08 13:39:31] USER1 DEPOSITs 26.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-09 13:39:31] USER1 DEPOSITs 56.36 SYS
# [2022-11-09 13:39:31] USER1 SWAPs 18.88 SYS for DAI
# [2022-11-09 13:39:31] USER1 WITHDRAWs 18.88 from DAI proceeds
# [2022-11-09 13:39:31] USER1 WITHDRAWs 29.03 SYS
# [2022-11-09 13:39:31] USER1 DEPOSITs 29.03 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-09 15:36:12] USER2 DEPOSITs 5522.13 SYS
# [2022-11-09 15:36:12] USER2 SWAPs 2761.07 SYS for DAI
# [2022-11-09 15:36:12] USER2 WITHDRAWs 2761.07 from DAI proceeds
# [2022-11-09 15:36:12] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-09 15:36:12] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-10 13:39:31] USER1 DEPOSITs 53.03 SYS
# [2022-11-10 13:39:31] USER1 SWAPs 14.94 SYS for DAI
# [2022-11-10 13:39:31] USER1 WITHDRAWs 14.94 from DAI proceeds
# [2022-11-10 13:39:31] USER1 WITHDRAWs 28.48 SYS
# [2022-11-10 13:39:31] USER1 DEPOSITs 28.48 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-11 06:56:21] USER2 DEPOSITs 5521.71 SYS
# [2022-11-11 06:56:21] USER2 SWAPs 2760.86 SYS for DAI
# [2022-11-11 06:56:21] USER2 WITHDRAWs 2760.86 from DAI proceeds
# [2022-11-11 06:56:21] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-11 06:56:21] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-11 13:39:31] USER1 DEPOSITs 51.75 SYS
# [2022-11-11 13:39:31] USER1 SWAPs 30.19 SYS for DAI
# [2022-11-11 13:39:31] USER1 WITHDRAWs 30.19 from DAI proceeds
# [2022-11-11 13:39:31] USER1 WITHDRAWs 23.05 SYS
# [2022-11-11 13:39:31] USER1 DEPOSITs 23.05 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-11 22:34:34] USER2 DEPOSITs 5521.29 SYS
# [2022-11-11 22:34:34] USER2 SWAPs 2760.64 SYS for DAI
# [2022-11-11 22:34:34] USER2 WITHDRAWs 2760.64 from DAI proceeds
# [2022-11-11 22:34:34] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-11 22:34:34] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 03:55:58] USER2 DEPOSITs 5520.86 SYS
# [2022-11-12 03:55:58] USER2 SWAPs 2760.43 SYS for DAI
# [2022-11-12 03:55:58] USER2 WITHDRAWs 2760.43 from DAI proceeds
# [2022-11-12 03:55:58] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-12 03:55:58] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 13:39:31] USER1 DEPOSITs 43.28 SYS
# [2022-11-12 13:39:31] USER1 SWAPs 24.39 SYS for DAI
# [2022-11-12 13:39:31] USER1 WITHDRAWs 24.39 from DAI proceeds
# [2022-11-12 13:39:31] USER1 WITHDRAWs 17.57 SYS
# [2022-11-12 13:39:31] USER1 DEPOSITs 17.57 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 14:55:48] USER2 DEPOSITs 5520.44 SYS
# [2022-11-12 14:55:48] USER2 SWAPs 2760.22 SYS for DAI
# [2022-11-12 14:55:48] USER2 WITHDRAWs 2760.22 from DAI proceeds
# [2022-11-12 14:55:48] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-12 14:55:48] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 15:05:45] USER2 DEPOSITs 5520.02 SYS
# [2022-11-12 15:05:45] USER2 SWAPs 2760.01 SYS for DAI
# [2022-11-12 15:05:45] USER2 WITHDRAWs 2760.01 from DAI proceeds
# [2022-11-12 15:05:45] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-12 15:05:45] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 16:04:21] USER2 DEPOSITs 5519.59 SYS
# [2022-11-12 16:04:21] USER2 SWAPs 2759.80 SYS for DAI
# [2022-11-12 16:04:21] USER2 WITHDRAWs 2759.80 from DAI proceeds
# [2022-11-12 16:04:21] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-12 16:04:21] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-12 21:01:09] USER2 DEPOSITs 5519.17 SYS
# [2022-11-12 21:01:09] USER2 SWAPs 2759.59 SYS for DAI
# [2022-11-12 21:01:09] USER2 WITHDRAWs 2759.59 from DAI proceeds
# [2022-11-12 21:01:09] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-12 21:01:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# ...
# [2023-02-21 13:39:31] USER1 SWAPs 18.08 SYS for DAI
# [2023-02-21 13:39:31] USER1 WITHDRAWs 18.08 from DAI proceeds
# [2023-02-21 13:39:31] USER1 WITHDRAWs 16.98 SYS
# [2023-02-21 13:39:31] USER1 DEPOSITs 16.98 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-22 02:00:15] USER2 DEPOSITs 5483.43 SYS
# [2023-02-22 02:00:15] USER2 SWAPs 2741.72 SYS for DAI
# [2023-02-22 02:00:15] USER2 WITHDRAWs 2741.72 from DAI proceeds
# [2023-02-22 02:00:15] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-22 02:00:15] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-22 13:39:31] USER1 DEPOSITs 49.14 SYS
# [2023-02-22 13:39:31] USER1 SWAPs 23.22 SYS for DAI
# [2023-02-22 13:39:31] USER1 WITHDRAWs 23.22 from DAI proceeds
# [2023-02-22 13:39:31] USER1 WITHDRAWs 34.39 SYS
# [2023-02-22 13:39:31] USER1 DEPOSITs 34.39 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-23 13:39:31] USER1 DEPOSITs 48.06 SYS
# [2023-02-23 13:39:31] USER1 SWAPs 29.14 SYS for DAI
# [2023-02-23 13:39:31] USER1 WITHDRAWs 29.14 from DAI proceeds
# [2023-02-23 13:39:31] USER1 WITHDRAWs 24.41 SYS
# [2023-02-23 13:39:31] USER1 DEPOSITs 24.41 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-24 13:39:31] USER1 DEPOSITs 48.56 SYS
# [2023-02-24 13:39:31] USER1 SWAPs 24.53 SYS for DAI
# [2023-02-24 13:39:31] USER1 WITHDRAWs 24.53 from DAI proceeds
# [2023-02-24 13:39:31] USER1 WITHDRAWs 34.29 SYS
# [2023-02-24 13:39:31] USER1 DEPOSITs 34.29 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-24 18:30:44] USER2 DEPOSITs 5483.02 SYS
# [2023-02-24 18:30:44] USER2 SWAPs 2741.51 SYS for DAI
# [2023-02-24 18:30:44] USER2 WITHDRAWs 2741.51 from DAI proceeds
# [2023-02-24 18:30:44] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-24 18:30:44] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-25 13:39:31] USER1 DEPOSITs 47.44 SYS
# [2023-02-25 13:39:31] USER1 SWAPs 28.00 SYS for DAI
# [2023-02-25 13:39:31] USER1 WITHDRAWs 28.00 from DAI proceeds
# [2023-02-25 13:39:31] USER1 WITHDRAWs 23.00 SYS
# [2023-02-25 13:39:31] USER1 DEPOSITs 23.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-25 19:55:09] USER2 DEPOSITs 5482.60 SYS
# [2023-02-25 19:55:09] USER2 SWAPs 2741.30 SYS for DAI
# [2023-02-25 19:55:09] USER2 WITHDRAWs 2741.30 from DAI proceeds
# [2023-02-25 19:55:09] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-25 19:55:09] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-26 13:39:31] USER1 DEPOSITs 40.38 SYS
# [2023-02-26 13:39:31] USER1 SWAPs 26.10 SYS for DAI
# [2023-02-26 13:39:31] USER1 WITHDRAWs 26.10 from DAI proceeds
# [2023-02-26 13:39:31] USER1 WITHDRAWs 27.00 SYS
# [2023-02-26 13:39:31] USER1 DEPOSITs 27.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-27 13:39:31] USER1 DEPOSITs 52.28 SYS
# [2023-02-27 13:39:31] USER1 SWAPs 21.63 SYS for DAI
# [2023-02-27 13:39:31] USER1 WITHDRAWs 21.63 from DAI proceeds
# [2023-02-27 13:39:31] USER1 WITHDRAWs 21.94 SYS
# [2023-02-27 13:39:31] USER1 DEPOSITs 21.94 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-28 13:39:31] USER1 DEPOSITs 50.99 SYS
# [2023-02-28 13:39:31] USER1 SWAPs 32.43 SYS for DAI
# [2023-02-28 13:39:31] USER1 WITHDRAWs 32.43 from DAI proceeds
# [2023-02-28 13:39:31] USER1 WITHDRAWs 28.51 SYS
# [2023-02-28 13:39:31] USER1 DEPOSITs 28.51 SYS_DAI_LP from SYS and DAI proceeds
# [2023-02-28 21:18:12] USER2 DEPOSITs 5482.18 SYS
# [2023-02-28 21:18:12] USER2 SWAPs 2741.09 SYS for DAI
# [2023-02-28 21:18:12] USER2 WITHDRAWs 2741.09 from DAI proceeds
# [2023-02-28 21:18:12] USER2 WITHDRAWs 2500.00 SYS
# [2023-02-28 21:18:12] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-01 12:51:20] USER2 DEPOSITs 5481.76 SYS
# [2023-03-01 12:51:20] USER2 SWAPs 2740.88 SYS for DAI
# [2023-03-01 12:51:20] USER2 WITHDRAWs 2740.88 from DAI proceeds
# [2023-03-01 12:51:20] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-01 12:51:20] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-01 13:39:31] USER1 DEPOSITs 45.90 SYS
# [2023-03-01 13:39:31] USER1 SWAPs 28.15 SYS for DAI
# [2023-03-01 13:39:31] USER1 WITHDRAWs 28.15 from DAI proceeds
# [2023-03-01 13:39:31] USER1 WITHDRAWs 26.03 SYS
# [2023-03-01 13:39:31] USER1 DEPOSITs 26.03 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-02 13:39:31] USER1 DEPOSITs 55.24 SYS
# [2023-03-02 13:39:31] USER1 SWAPs 34.47 SYS for DAI
# [2023-03-02 13:39:31] USER1 WITHDRAWs 34.47 from DAI proceeds
# [2023-03-02 13:39:31] USER1 WITHDRAWs 27.64 SYS
# [2023-03-02 13:39:31] USER1 DEPOSITs 27.64 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-03 13:39:31] USER1 DEPOSITs 60.14 SYS
# [2023-03-03 13:39:31] USER1 SWAPs 30.74 SYS for DAI
# [2023-03-03 13:39:31] USER1 WITHDRAWs 30.74 from DAI proceeds
# [2023-03-03 13:39:31] USER1 WITHDRAWs 22.45 SYS
# [2023-03-03 13:39:31] USER1 DEPOSITs 22.45 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-04 00:10:00] USER2 DEPOSITs 5481.35 SYS
# [2023-03-04 00:10:00] USER2 SWAPs 2740.67 SYS for DAI
# [2023-03-04 00:10:00] USER2 WITHDRAWs 2740.67 from DAI proceeds
# [2023-03-04 00:10:00] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-04 00:10:00] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-04 13:39:31] USER1 DEPOSITs 51.02 SYS
# [2023-03-04 13:39:31] USER1 SWAPs 16.33 SYS for DAI
# [2023-03-04 13:39:31] USER1 WITHDRAWs 16.33 from DAI proceeds
# [2023-03-04 13:39:31] USER1 WITHDRAWs 31.31 SYS
# [2023-03-04 13:39:31] USER1 DEPOSITs 31.31 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-05 13:39:31] USER1 DEPOSITs 47.05 SYS
# [2023-03-05 13:39:31] USER1 SWAPs 27.04 SYS for DAI
# [2023-03-05 13:39:31] USER1 WITHDRAWs 27.04 from DAI proceeds
# [2023-03-05 13:39:31] USER1 WITHDRAWs 31.84 SYS
# [2023-03-05 13:39:31] USER1 DEPOSITs 31.84 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-05 15:54:45] USER2 DEPOSITs 5480.93 SYS
# [2023-03-05 15:54:45] USER2 SWAPs 2740.46 SYS for DAI
# [2023-03-05 15:54:45] USER2 WITHDRAWs 2740.46 from DAI proceeds
# [2023-03-05 15:54:45] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-05 15:54:45] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-06 13:39:31] USER1 DEPOSITs 43.31 SYS
# [2023-03-06 13:39:31] USER1 SWAPs 29.60 SYS for DAI
# [2023-03-06 13:39:31] USER1 WITHDRAWs 29.60 from DAI proceeds
# [2023-03-06 13:39:31] USER1 WITHDRAWs 28.09 SYS
# [2023-03-06 13:39:31] USER1 DEPOSITs 28.09 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-07 10:38:18] USER2 DEPOSITs 5480.51 SYS
# [2023-03-07 10:38:18] USER2 SWAPs 2740.26 SYS for DAI
# [2023-03-07 10:38:18] USER2 WITHDRAWs 2740.26 from DAI proceeds
# [2023-03-07 10:38:18] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-07 10:38:18] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-07 22:04:42] USER2 DEPOSITs 5480.09 SYS
# [2023-03-07 22:04:42] USER2 SWAPs 2740.05 SYS for DAI
# [2023-03-07 22:04:42] USER2 WITHDRAWs 2740.05 from DAI proceeds
# [2023-03-07 22:04:42] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-07 22:04:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-08 07:46:35] USER2 DEPOSITs 5479.68 SYS
# [2023-03-08 07:46:35] USER2 SWAPs 2739.84 SYS for DAI
# [2023-03-08 07:46:35] USER2 WITHDRAWs 2739.84 from DAI proceeds
# [2023-03-08 07:46:35] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-08 07:46:35] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-10 14:42:18] USER2 DEPOSITs 5479.26 SYS
# [2023-03-10 14:42:18] USER2 SWAPs 2739.63 SYS for DAI
# [2023-03-10 14:42:18] USER2 WITHDRAWs 2739.63 from DAI proceeds
# [2023-03-10 14:42:18] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-10 14:42:18] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-11 13:09:20] USER2 DEPOSITs 5478.84 SYS
# [2023-03-11 13:09:20] USER2 SWAPs 2739.42 SYS for DAI
# [2023-03-11 13:09:20] USER2 WITHDRAWs 2739.42 from DAI proceeds
# [2023-03-11 13:09:20] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-11 13:09:20] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-11 14:55:16] USER2 DEPOSITs 5478.43 SYS
# [2023-03-11 14:55:16] USER2 SWAPs 2739.21 SYS for DAI
# [2023-03-11 14:55:16] USER2 WITHDRAWs 2739.21 from DAI proceeds
# [2023-03-11 14:55:16] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-11 14:55:16] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-12 06:59:59] USER2 DEPOSITs 5478.01 SYS
# [2023-03-12 06:59:59] USER2 SWAPs 2739.00 SYS for DAI
# [2023-03-12 06:59:59] USER2 WITHDRAWs 2739.00 from DAI proceeds
# [2023-03-12 06:59:59] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-12 06:59:59] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-12 15:00:15] USER2 DEPOSITs 5477.59 SYS
# [2023-03-12 15:00:15] USER2 SWAPs 2738.80 SYS for DAI
# [2023-03-12 15:00:15] USER2 WITHDRAWs 2738.80 from DAI proceeds
# [2023-03-12 15:00:15] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-12 15:00:15] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-12 23:52:45] USER2 DEPOSITs 5477.17 SYS
# [2023-03-12 23:52:45] USER2 SWAPs 2738.59 SYS for DAI
# [2023-03-12 23:52:45] USER2 WITHDRAWs 2738.59 from DAI proceeds
# [2023-03-12 23:52:45] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-12 23:52:45] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-13 00:38:43] USER2 DEPOSITs 5476.76 SYS
# [2023-03-13 00:38:43] USER2 SWAPs 2738.38 SYS for DAI
# [2023-03-13 00:38:43] USER2 WITHDRAWs 2738.38 from DAI proceeds
# [2023-03-13 00:38:43] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-13 00:38:43] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-13 23:35:17] USER2 DEPOSITs 5476.34 SYS
# [2023-03-13 23:35:17] USER2 SWAPs 2738.17 SYS for DAI
# [2023-03-13 23:35:17] USER2 WITHDRAWs 2738.17 from DAI proceeds
# [2023-03-13 23:35:17] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-13 23:35:17] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-14 05:08:10] USER2 DEPOSITs 5475.92 SYS
# [2023-03-14 05:08:10] USER2 SWAPs 2737.96 SYS for DAI
# [2023-03-14 05:08:10] USER2 WITHDRAWs 2737.96 from DAI proceeds
# [2023-03-14 05:08:10] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-14 05:08:10] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-17 21:41:48] USER2 DEPOSITs 5475.51 SYS
# [2023-03-17 21:41:48] USER2 SWAPs 2737.75 SYS for DAI
# [2023-03-17 21:41:48] USER2 WITHDRAWs 2737.75 from DAI proceeds
# [2023-03-17 21:41:48] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-17 21:41:48] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-18 05:25:05] USER2 DEPOSITs 5475.09 SYS
# [2023-03-18 05:25:05] USER2 SWAPs 2737.55 SYS for DAI
# [2023-03-18 05:25:05] USER2 WITHDRAWs 2737.55 from DAI proceeds
# [2023-03-18 05:25:05] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-18 05:25:05] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-18 14:02:20] USER2 DEPOSITs 5474.68 SYS
# [2023-03-18 14:02:20] USER2 SWAPs 2737.34 SYS for DAI
# [2023-03-18 14:02:20] USER2 WITHDRAWs 2737.34 from DAI proceeds
# [2023-03-18 14:02:20] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-18 14:02:20] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-19 09:08:19] USER2 DEPOSITs 5474.26 SYS
# [2023-03-19 09:08:19] USER2 SWAPs 2737.13 SYS for DAI
# [2023-03-19 09:08:19] USER2 WITHDRAWs 2737.13 from DAI proceeds
# [2023-03-19 09:08:19] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-19 09:08:19] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-19 18:17:07] USER2 DEPOSITs 5473.84 SYS
# [2023-03-19 18:17:07] USER2 SWAPs 2736.92 SYS for DAI
# [2023-03-19 18:17:07] USER2 WITHDRAWs 2736.92 from DAI proceeds
# [2023-03-19 18:17:07] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-19 18:17:07] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-21 07:17:33] USER2 DEPOSITs 5473.43 SYS
# [2023-03-21 07:17:33] USER2 SWAPs 2736.71 SYS for DAI
# [2023-03-21 07:17:33] USER2 WITHDRAWs 2736.71 from DAI proceeds
# [2023-03-21 07:17:33] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-21 07:17:33] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-21 14:10:20] USER2 DEPOSITs 5473.01 SYS
# [2023-03-21 14:10:20] USER2 SWAPs 2736.50 SYS for DAI
# [2023-03-21 14:10:20] USER2 WITHDRAWs 2736.50 from DAI proceeds
# [2023-03-21 14:10:20] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-21 14:10:20] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-26 06:18:31] USER2 DEPOSITs 5472.59 SYS
# [2023-03-26 06:18:31] USER2 SWAPs 2736.30 SYS for DAI
# [2023-03-26 06:18:31] USER2 WITHDRAWs 2736.30 from DAI proceeds
# [2023-03-26 06:18:31] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-26 06:18:31] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-26 07:59:14] USER2 DEPOSITs 5472.18 SYS
# [2023-03-26 07:59:14] USER2 SWAPs 2736.09 SYS for DAI
# [2023-03-26 07:59:14] USER2 WITHDRAWs 2736.09 from DAI proceeds
# [2023-03-26 07:59:14] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-26 07:59:14] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-27 23:00:10] USER2 DEPOSITs 5471.76 SYS
# [2023-03-27 23:00:10] USER2 SWAPs 2735.88 SYS for DAI
# [2023-03-27 23:00:10] USER2 WITHDRAWs 2735.88 from DAI proceeds
# [2023-03-27 23:00:10] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-27 23:00:10] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-27 23:07:04] USER2 DEPOSITs 5471.35 SYS
# [2023-03-27 23:07:04] USER2 SWAPs 2735.67 SYS for DAI
# [2023-03-27 23:07:04] USER2 WITHDRAWs 2735.67 from DAI proceeds
# [2023-03-27 23:07:04] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-27 23:07:04] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-28 18:31:42] USER2 DEPOSITs 5470.93 SYS
# [2023-03-28 18:31:42] USER2 SWAPs 2735.47 SYS for DAI
# [2023-03-28 18:31:42] USER2 WITHDRAWs 2735.47 from DAI proceeds
# [2023-03-28 18:31:42] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-28 18:31:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-29 15:45:27] USER2 DEPOSITs 5470.51 SYS
# [2023-03-29 15:45:27] USER2 SWAPs 2735.26 SYS for DAI
# [2023-03-29 15:45:27] USER2 WITHDRAWs 2735.26 from DAI proceeds
# [2023-03-29 15:45:27] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-29 15:45:27] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-31 12:45:24] USER2 DEPOSITs 5470.10 SYS
# [2023-03-31 12:45:24] USER2 SWAPs 2735.05 SYS for DAI
# [2023-03-31 12:45:24] USER2 WITHDRAWs 2735.05 from DAI proceeds
# [2023-03-31 12:45:24] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-31 12:45:24] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-31 23:17:18] USER2 DEPOSITs 5469.68 SYS
# [2023-03-31 23:17:18] USER2 SWAPs 2734.84 SYS for DAI
# [2023-03-31 23:17:18] USER2 WITHDRAWs 2734.84 from DAI proceeds
# [2023-03-31 23:17:18] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-31 23:17:18] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-02 16:51:22] USER2 DEPOSITs 5469.27 SYS
# [2023-04-02 16:51:22] USER2 SWAPs 2734.63 SYS for DAI
# [2023-04-02 16:51:22] USER2 WITHDRAWs 2734.63 from DAI proceeds
# [2023-04-02 16:51:22] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-02 16:51:22] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-02 21:56:26] USER2 DEPOSITs 5468.85 SYS
# [2023-04-02 21:56:26] USER2 SWAPs 2734.43 SYS for DAI
# [2023-04-02 21:56:26] USER2 WITHDRAWs 2734.43 from DAI proceeds
# [2023-04-02 21:56:26] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-02 21:56:26] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-03 00:37:51] USER2 DEPOSITs 5468.44 SYS
# [2023-04-03 00:37:51] USER2 SWAPs 2734.22 SYS for DAI
# [2023-04-03 00:37:51] USER2 WITHDRAWs 2734.22 from DAI proceeds
# [2023-04-03 00:37:51] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-03 00:37:51] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-03 03:02:48] USER2 DEPOSITs 5468.02 SYS
# [2023-04-03 03:02:48] USER2 SWAPs 2734.01 SYS for DAI
# [2023-04-03 03:02:48] USER2 WITHDRAWs 2734.01 from DAI proceeds
# [2023-04-03 03:02:48] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-03 03:02:48] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-03 09:14:46] USER2 DEPOSITs 5467.61 SYS
# [2023-04-03 09:14:46] USER2 SWAPs 2733.80 SYS for DAI
# [2023-04-03 09:14:46] USER2 WITHDRAWs 2733.80 from DAI proceeds
# [2023-04-03 09:14:46] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-03 09:14:46] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-04 22:31:50] USER2 DEPOSITs 5467.19 SYS
# [2023-04-04 22:31:50] USER2 SWAPs 2733.60 SYS for DAI
# [2023-04-04 22:31:50] USER2 WITHDRAWs 2733.60 from DAI proceeds
# [2023-04-04 22:31:50] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-04 22:31:50] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds

# %% [markdown]
# ### Analyze

# %%
tSYS = SYS.get_token()
tDAI = DAI.get_token()
tSYS_DAI = SYS_DAI.get_token()

SYS_addr1 = SYS.get_address(SYS_mint1.get_id())
DAI_addr1 = DAI.get_address(DAI_mint1.get_id())
SYS_DAI_addr1 = SYS_DAI.get_address(SYS_DAI_LP_mint1.get_id())

# %%
SYS_states1 = tSYS.get_state_series(SYS_addr1)
principle = SYS_states1.get_principle() 
balance = SYS_states1.get_balance() 
tSamp = SYS_states1.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_ax.set_title("USER1: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states1 = tDAI.get_state_series(DAI_addr1)
principle = DAI_states1.get_principle() 
balance = DAI_states1.get_balance() 
tSamp = DAI_states1.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER1: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states1 = tSYS_DAI.get_state_series(SYS_DAI_addr1)
principle = SYS_DAI_states1.get_principle() 
balance = SYS_DAI_states1.get_balance() 
tSamp = SYS_DAI_states1.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
SYS_addr2 = SYS.get_address(SYS_mint2.get_id())
DAI_addr2 = DAI.get_address(DAI_mint2.get_id())
SYS_DAI_addr2 = SYS_DAI.get_address(SYS_DAI_LP_mint2.get_id())

# %%
SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp()

# %%
# Analyze Token balances

SYS_states2 = tSYS.get_state_series(SYS_addr2)
principle = SYS_states2.get_principle() 
balance = SYS_states2.get_balance() 
tSamp = SYS_states2.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp, balance, label='balance') 
SYS_ax.plot(tSamp, principle, label='principle') 
SYS_ax.set_title("USER2: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states2 = tDAI.get_state_series(DAI_addr2)
principle = DAI_states2.get_principle() 
balance = DAI_states2.get_balance() 
tSamp = DAI_states2.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER2: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
tSamp = SYS_DAI_LP.get_lp_events().get_dates()
utSamp = SYS_DAI_LP.get_lp_events().get_unix_time_stamps()
prices = SYS_DAI_LP.get_lp_events().get_prices()
liquidities = SYS_DAI_LP.get_lp_events().get_liquidity_values()
balances = SYS_DAI_LP.get_lp_events().gen_yield_balances(apy)

fig, (liq_ax) = plt.subplots(nrows=1, sharex=True, sharey=False, figsize=(18, 15))

liq_ax.plot(tSamp, liquidities, label='liquidities') 
liq_ax.plot(tSamp, balances, label='liquidities') 
liq_ax.set_title("Total SYS_DAI_LP Balance (rebasing token)", fontsize=20)
liq_ax.set_ylabel("Token balance", fontsize=16)
liq_ax.set_xlabel('Time', fontsize=16)
liq_ax.legend()
