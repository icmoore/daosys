# %% [markdown]
# ### Simulation: Masternode Yield Farming

# %%
import os
import copy
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from IPython.display import Image
cwd =  os.getcwd().replace("notebooks/simulation","")
os.chdir(cwd)

from python.dev.helper import Helper

from python.dev.simulation import SimulationOrchestrator
from python.dev.simulation import EventQueue
from python.dev.simulation import EventExecutor
from python.dev.simulation.batch import ActionBatch
from python.dev.simulation.batch import MergeBatch

from python.dev.agent import TokenAgent
from python.dev.agent import LPTokenAgent
from python.dev.agent import UserAgent

from python.dev.action import MintAction
from python.dev.action import DepositAction
from python.dev.action import LPDepositChainAction
from python.dev.action import DepositChainAction
from python.dev.action import WithdrawChainAction
from python.dev.action import WithdrawAction
from python.dev.action import SwapAction
from python.dev.event import Mint
from python.dev.event import Deposit
from python.dev.event import Withdraw
from python.dev.event import Swap

from python.dev.math.model import TokenDeltaModel
from python.dev.math.model import TimeDeltaModel
from python.dev.math.model import ModelQueue

from python.dev.lp import LiquidityPool
from python.dev.lp.event import LPEvent
from python.dev.lp.event import MintLPEvent
from python.dev.lp.event import DepositLPEvent
from python.dev.lp.event import SwapLPEvent

# %%
Image("images/jupyter/tutorials/masternode_nft.png", width = 600, height = 600)

# %% [markdown]
# ### Load Data

# %%
daosys_proj = pd.read_csv('notebooks/resources/daosys_proj.csv')

# %% [markdown]
# ### Initialize Agents

# %%
USER1 = UserAgent('USER1')
USER2 = UserAgent('USER2')

SYS = TokenAgent('SYS')
DAI = TokenAgent('DAI')

SYS_DAI_LP = LiquidityPool('SYS/DAI', USER1, SYS, DAI)
SYS_DAI = LPTokenAgent('SYS_DAI_LP', SYS_DAI_LP)

# %% [markdown]
# ### Mint Tokens

# %%
apy = 0.1
t_delta = 109*24*3600

# %%
SYS_mint1 = Mint(5000, apy, True)
DAI_mint1 = Mint(5000, apy, True)
SYS_DAI_LP_mint1 = Mint(0, apy, True)

SYS_mint2 = Mint(100000, apy, True)
DAI_mint2 = Mint(0, apy, True)
SYS_mint3 = Mint(1000, apy, True)
SYS_DAI_LP_mint2 = Mint(0, apy, True)

# %%
m_action1 = MintAction(SYS_mint1, SYS, USER1)
m_action2 = MintAction(DAI_mint1, DAI, USER1)
m_action3 = MintAction(SYS_DAI_LP_mint1, SYS_DAI, USER1)

m_action4 = MintAction(SYS_mint2, SYS, USER2)
m_action5 = MintAction(DAI_mint2, DAI, USER2)
m_action6 = MintAction(SYS_DAI_LP_mint2, SYS_DAI, USER2)
m_action7 = MintAction(SYS_mint3, SYS, USER1)

# %% [markdown]
# ### Setup Actions

# %%
sub_withdraw1 = Withdraw(apy, 2500, 0) 
sub_withdraw2 = Withdraw(apy, 2500, 0) 
w_action1 = WithdrawAction(sub_withdraw1, SYS, USER1, SYS_mint1.get_id())
w_action2 = WithdrawAction(sub_withdraw2, DAI, USER1, DAI_mint1.get_id())
d_action1 = LPDepositChainAction(w_action1, w_action2, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %%
sBatch1 = ActionBatch('SETUP1')
sBatch1.init_action(m_action1)
sBatch1.init_action(m_action2)
sBatch1.init_action(m_action3)
sBatch1.init_action(w_action1)
sBatch1.init_action(w_action2)
sBatch1.init_action(d_action1)
sBatch1.inspect()

setup_batch1 = sBatch1.generate()
# Out:
# ** SETUP1 INIT BATCH **
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# USER1 WITHDRAWs SYS
# USER1 WITHDRAWs DAI
# USER1 DEPOSITs SYS and DAI proceeds into SYS_DAI_LP

# %%
sBatch2 = ActionBatch('SETUP2')
sBatch2.init_action(m_action4)
sBatch2.init_action(m_action5)
sBatch2.init_action(m_action6)
sBatch2.init_action(m_action7)
sBatch2.inspect()

setup_batch2 = sBatch2.generate()
# Out:
# ** SETUP2 INIT BATCH **
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS

# %% [markdown]
# ### Batchset 1

# %%
deposit_obj1 = ModelQueue().apply(daosys_proj['mn_nsys'].values, 200)
withdraw_obj2 = ModelQueue().apply(daosys_proj['mn_nsys'].values/2, 200)
t_delta_model = TimeDeltaModel().apply(p = 0.00001, n = 200)
t_delta_obj1 = ModelQueue().apply(t_delta_model)
t_delta_obj2 = ModelQueue().apply(t_delta_model)
t_delta = 3600*24

# %%
deposit1 = Deposit(apy, deposit_obj1, t_delta_obj1) 
sub_withdraw1 = Withdraw(apy, 2500, 0)
sub_deposit1 = Deposit(apy, withdraw_obj2, t_delta_obj2)
withdraw1 = Withdraw(apy, 2500, 0)

# %%
# Deposit 5000 SYS
d_action2 = DepositAction(deposit1, SYS, USER2, SYS_mint2.get_id())

# Swap 2500 SYS for DAI
sub_w_action1 = WithdrawAction(sub_withdraw1, SYS, USER2, SYS_mint2.get_id())
sub_d_action1 = DepositAction(sub_deposit1, DAI, USER2, DAI_mint2.get_id())
s_action1 = SwapAction(sub_w_action1, sub_d_action1)

# Withdraw DAI proceeds and 2500 SYS
w_action3 = WithdrawChainAction(s_action1, DAI, USER2, DAI_mint2.get_id())
w_action4 = WithdrawAction(withdraw1, SYS, USER2, SYS_mint2.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action3 = LPDepositChainAction(w_action3, w_action4, SYS_DAI, USER1, SYS_DAI_LP_mint2.get_id())

# %%
aBatch1 = ActionBatch('RUN1', 200)
aBatch1.add_action(d_action2)
aBatch1.add_action(s_action1)
aBatch1.add_action(w_action3)
aBatch1.add_action(w_action4)
aBatch1.add_action(d_action3)
aBatch1.inspect()

action_batch1 = aBatch1.generate()
# Out:
# ** RUN1 ACTION BATCH **
# USER2 DEPOSITs SYS
# USER2 SWAPs SYS for DAI
# USER2 WITHDRAWs DAI proceeds
# USER2 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 12057 seconds

# %% [markdown]
# ### Batchset 2

# %%
r_deposit_obj = ModelQueue().apply(np.random.normal(50, 5, 200))
r_withdraw_obj = ModelQueue().apply(np.random.normal(25, 5, 200))

r_swap_model = np.random.normal(25, 5, 200)
r_sub_withdraw_obj = ModelQueue().apply(r_swap_model)
r_sub_deposit_obj = ModelQueue().apply(r_swap_model)

t_delta_model = TimeDeltaModel().apply(p = 0.00001, n = 200)
t_delta_obj3 = ModelQueue().apply(t_delta_model)
t_delta_obj4 = ModelQueue().apply(t_delta_model)

deposit2 = Deposit(apy, r_deposit_obj, t_delta_obj3) 
sub_withdraw2 = Withdraw(apy, r_sub_withdraw_obj, 0)
sub_deposit2 = Deposit(apy, r_sub_deposit_obj, t_delta_obj4)
withdraw2 = Withdraw(apy, r_withdraw_obj, 0)

# %%
# Deposit 50 SYS
d_action4 = DepositAction(deposit2, SYS, USER1, SYS_mint1.get_id())

# Swap 2500 SYS for DAI
sub_w_action2 = WithdrawAction(sub_withdraw2, SYS, USER1, SYS_mint1.get_id())
sub_d_action2 = DepositAction(sub_deposit2, DAI, USER1, DAI_mint1.get_id())
s_action2 = SwapAction(sub_w_action2, sub_d_action2)

# Withdraw DAI proceeds and 2500 SYS
w_action5 = WithdrawChainAction(s_action2, DAI, USER1, DAI_mint1.get_id())
w_action6 = WithdrawAction(withdraw2, SYS, USER1, SYS_mint1.get_id())

# Deposit withdrawn DAI and SYS in LP
d_action5 = LPDepositChainAction(w_action5, w_action6, SYS_DAI, USER1, SYS_DAI_LP_mint1.get_id())

# %%
aBatch2 = ActionBatch('RUN2', 200)
aBatch2.add_action(d_action4)
aBatch2.add_action(s_action2)
aBatch2.add_action(w_action5)
aBatch2.add_action(w_action6)
aBatch2.add_action(d_action5)
aBatch2.inspect()

action_batch2 = aBatch2.generate()
# Out:
# ** RUN2 ACTION BATCH **
# USER1 DEPOSITs SYS
# USER1 SWAPs SYS for DAI
# USER1 WITHDRAWs DAI proceeds
# USER1 WITHDRAWs SYS
# USER1 DEPOSITs DAI and SYS proceeds into SYS_DAI_LP
#
#  ** REPEAT BATCH **
#  200 times
#
#  ** RUNTIME for 1st BATCH **
# 218198 seconds

# %% [markdown]
# ### Setup event queue

# %%
q = EventQueue()
q.add_setup_batch(setup_batch1)
q.add_setup_batch(setup_batch2)
q.add_action_batch(action_batch1)
q.add_action_batch(action_batch2)
q.freeze()

event_batches = q.get_event_batches()

# %% [markdown]
# ### Execute events

# %%
orchestrator = SimulationOrchestrator(verbose = True)
executor = EventExecutor(q, orchestrator)
executor.run()
# Out:
# ======== Action Events ===========
# # num_events: 2010
#
# USER1 MINTs 5000.00 SYS
# USER1 MINTs 5000.00 DAI
# USER1 MINTs 0.00 SYS_DAI_LP
# [2022-08-18 17:44:03] USER1 WITHDRAWs 2500.00 SYS
# [2022-08-18 17:44:03] USER1 WITHDRAWs 2500.00 DAI
# [2022-08-18 17:44:03] USER1 DEPOSITs 2500.00 SYS_DAI_LP from DAI and SYS proceeds
# USER2 MINTs 100000.00 SYS
# USER2 MINTs 0.00 DAI
# USER2 MINTs 0.00 SYS_DAI_LP
# USER1 MINTs 1000.00 SYS
# [2022-08-18 21:05:00] USER2 DEPOSITs 5551.09 SYS
# [2022-08-18 21:05:00] USER2 SWAPs 2775.55 SYS for DAI
# [2022-08-18 21:05:00] USER2 WITHDRAWs 2775.55 from DAI proceeds
# [2022-08-18 21:05:00] USER2 WITHDRAWs 2500.00 SYS
# [2022-08
SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-24 00:10:54] USER1 DEPOSITs 45.90 SYS
# [2022-11-24 00:10:54] USER1 SWAPs 24.63 SYS for DAI
# [2022-11-24 00:10:54] USER1 WITHDRAWs 24.63 from DAI proceeds
# [2022-11-24 00:10:54] USER1 WITHDRAWs 26.36 SYS
# [2022-11-24 00:10:54] USER1 DEPOSITs 26.36 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-25 12:14:10] USER2 DEPOSITs 5520.44 SYS
# [2022-11-25 12:14:10] USER2 SWAPs 2760.22 SYS for DAI
# [2022-11-25 12:14:10] USER2 WITHDRAWs 2760.22 from DAI proceeds
# [2022-11-25 12:14:10] USER2 WITHDRAWs 2500.00 SYS
# [2022-11-25 12:14:10] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-25 12:16:03] USER1 DEPOSITs 45.41 SYS
# [2022-11-25 12:16:03] USER1 SWAPs 25.92 SYS for DAI
# [2022-11-25 12:16:03] USER1 WITHDRAWs 25.92 from DAI proceeds
# [2022-11-25 12:16:03] USER1 WITHDRAWs 25.15 SYS
# [2022-11-25 12:16:03] USER1 DEPOSITs 25.15 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-27 00:00:25] USER1 DEPOSITs 42.94 SYS
# [2022-11-27 00:00:25] USER1 SWAPs 24.98 SYS for DAI
# [2022-11-27 00:00:25] USER1 WITHDRAWs 24.98 from DAI proceeds
# [2022-11-27 00:00:25] USER1 WITHDRAWs 31.52 SYS
# [2022-11-27 00:00:25] USER1 DEPOSITs 31.52 SYS_DAI_LP from SYS and DAI proceeds
# [2022-11-28 04:56:06] USER1 DEPOSITs 52.11 SYS
# [2022-11-28 04:56:06] USER1 SWAPs 17.97 SYS for DAI
# [2022-11-28 04:56:06] USER1 WITHDRAWs 17.97 from DAI proceeds
# [2022-11-28 04:56:06] USER1 WITHDRAWs 35.39 SYS
# [2022-11-28 04:56:06] USER1 DEPOSITs 35.39 SYS_DAI_LP from SYS and DAI proceeds
# ...
# [2023-03-15 17:09:18] USER1 WITHDRAWs 23.57 SYS
# [2023-03-15 17:09:18] USER1 DEPOSITs 23.57 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-15 18:44:52] USER1 DEPOSITs 52.12 SYS
# [2023-03-15 18:44:52] USER1 SWAPs 24.37 SYS for DAI
# [2023-03-15 18:44:52] USER1 WITHDRAWs 24.37 from DAI proceeds
# [2023-03-15 18:44:52] USER1 WITHDRAWs 24.46 SYS
# [2023-03-15 18:44:52] USER1 DEPOSITs 24.46 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-16 04:33:40] USER2 DEPOSITs 5477.59 SYS
# [2023-03-16 04:33:40] USER2 SWAPs 2738.80 SYS for DAI
# [2023-03-16 04:33:40] USER2 WITHDRAWs 2738.80 from DAI proceeds
# [2023-03-16 04:33:40] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-16 04:33:40] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-16 12:01:29] USER1 DEPOSITs 46.26 SYS
# [2023-03-16 12:01:29] USER1 SWAPs 26.28 SYS for DAI
# [2023-03-16 12:01:29] USER1 WITHDRAWs 26.28 from DAI proceeds
# [2023-03-16 12:01:29] USER1 WITHDRAWs 20.98 SYS
# [2023-03-16 12:01:29] USER1 DEPOSITs 20.98 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-18 04:01:28] USER1 DEPOSITs 55.44 SYS
# [2023-03-18 04:01:28] USER1 SWAPs 25.73 SYS for DAI
# [2023-03-18 04:01:28] USER1 WITHDRAWs 25.73 from DAI proceeds
# [2023-03-18 04:01:28] USER1 WITHDRAWs 25.21 SYS
# [2023-03-18 04:01:28] USER1 DEPOSITs 25.21 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03
USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-26 01:34:22] USER1 DEPOSITs 42.95 SYS
# [2023-03-26 01:34:22] USER1 SWAPs 23.78 SYS for DAI
# [2023-03-26 01:34:22] USER1 WITHDRAWs 23.78 from DAI proceeds
# [2023-03-26 01:34:22] USER1 WITHDRAWs 24.70 SYS
# [2023-03-26 01:34:22] USER1 DEPOSITs 24.70 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-26 21:34:40] USER2 DEPOSITs 5474.26 SYS
# [2023-03-26 21:34:40] USER2 SWAPs 2737.13 SYS for DAI
# [2023-03-26 21:34:40] USER2 WITHDRAWs 2737.13 from DAI proceeds
# [2023-03-26 21:34:40] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-26 21:34:40] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-27 07:30:10] USER2 DEPOSITs 5473.84 SYS
# [2023-03-27 07:30:10] USER2 SWAPs 2736.92 SYS for DAI
# [2023-03-27 07:30:10] USER2 WITHDRAWs 2736.92 from DAI proceeds
# [2023-03-27 07:30:10] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-27 07:30:10] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-27 08:06:31] USER1 DEPOSITs 49.41 SYS
# [2023-03-27 08:06:31] USER1 SWAPs 23.52 SYS for DAI
# [2023-03-27 08:06:31] USER1 WITHDRAWs 23.52 from DAI proceeds
# [2023-03-27 08:06:31] USER1 WITHDRAWs 23.34 SYS
# [2023-03-27 08:06:31] USER1 DEPOSITs 23.34 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-27 14:44:40] USER2 DEPOSITs 5473.43 SYS
# [2023-03-27 14:44:40] USER2 SWAPs 2736.71 SYS for DAI
# [2023-03-27 14:44:40] USER2 WITHDRAWs 2736.71 from DAI proceeds
# [2023-03-27 14:44:40] USER2 WITHDRAWs 2500.00 SYS
# [2023-03-27 14:44:40] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-28 05:14:24] USER1 DEPOSITs 52.08 SYS
# [2023-03-28 05:14:24] USER1 SWAPs 23.94 SYS for DAI
# [2023-03-28 05:14:24] USER1 WITHDRAWs 23.94 from DAI proceeds
# [2023-03-28 05:14:24] USER1 WITHDRAWs 21.86 SYS
# [2023-03-28 05:14:24] USER1 DEPOSITs 21.86 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-29 13:46:49] USER1 DEPOSITs 42.36 SYS
# [2023-03-29 13:46:49] USER1 SWAPs 23.79 SYS for DAI
# [2023-03-29 13:46:49] USER1 WITHDRAWs 23.79 from DAI proceeds
# [2023-03-29 13:46:49] USER1 WITHDRAWs 21.48 SYS
# [2023-03-29 13:46:49] USER1 DEPOSITs 21.48 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-31 14:41:24] USER1 DEPOSITs 50.97 SYS
# [2023-03-31 14:41:24] USER1 SWAPs 17.66 SYS for DAI
# [2023-03-31 14:41:24] USER1 WITHDRAWs 17.66 from DAI proceeds
# [2023-03-31 14:41:24] USER1 WITHDRAWs 15.85 SYS
# [2023-03-31 14:41:24] USER1 DEPOSITs 15.85 SYS_DAI_LP from SYS and DAI proceeds
# [2023-03-31 22:57:03] USER1 DEPOSITs 46.37 SYS
# [2023-03-31 22:57:03] USER1 SWAPs 26.24 SYS for DAI
# [2023-03-31 22:57:03] USER1 WITHDRAWs 26.24 from DAI proceeds
# [2023-03-31 22:57:03] USER1 WITHDRAWs 18.27 SYS
# [2023-03-31 22:57:03] USER1 DEPOSITs 18.27 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-01 04:40:42] USER2 DEPOSITs 5473.01 SYS
# [2023-04-01 04:40:42] USER2 SWAPs 2736.50 SYS for DAI
# [2023-04-01 04:40:42] USER2 WITHDRAWs 2736.50 from DAI proceeds
# [2023-04-01 04:40:42] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-01 04:40:42] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-02 02:03:49] USER2 DEPOSITs 5472.59 SYS
# [2023-04-02 02:03:49] USER2 SWAPs 2736.30 SYS for DAI
# [2023-04-02 02:03:49] USER2 WITHDRAWs 2736.30 from DAI proceeds
# [2023-04-02 02:03:49] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-02 02:03:49] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-04 15:42:02] USER2 DEPOSITs 5472.18 SYS
# [2023-04-04 15:42:02] USER2 SWAPs 2736.09 SYS for DAI
# [2023-04-04 15:42:02] USER2 WITHDRAWs 2736.09 from DAI proceeds
# [2023-04-04 15:42:02] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-04 15:42:02] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-05 00:11:48] USER2 DEPOSITs 5471.76 SYS
# [2023-04-05 00:11:48] USER2 SWAPs 2735.88 SYS for DAI
# [2023-04-05 00:11:48] USER2 WITHDRAWs 2735.88 from DAI proceeds
# [2023-04-05 00:11:48] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-05 00:11:48] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-05 17:28:10] USER1 DEPOSITs 46.18 SYS
# [2023-04-05 17:28:10] USER1 SWAPs 21.88 SYS for DAI
# [2023-04-05 17:28:10] USER1 WITHDRAWs 21.88 from DAI proceeds
# [2023-04-05 17:28:10] USER1 WITHDRAWs 14.11 SYS
# [2023-04-05 17:28:10] USER1 DEPOSITs 14.11 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-05 21:19:22] USER1 DEPOSITs 52.33 SYS
# [2023-04-05 21:19:22] USER1 SWAPs 33.25 SYS for DAI
# [2023-04-05 21:19:22] USER1 WITHDRAWs 33.25 from DAI proceeds
# [2023-04-05 21:19:22] USER1 WITHDRAWs 31.95 SYS
# [2023-04-05 21:19:22] USER1 DEPOSITs 31.95 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-06 23:14:15] USER1 DEPOSITs 60.43 SYS
# [2023-04-06 23:14:15] USER1 SWAPs 29.30 SYS for DAI
# [2023-04-06 23:14:15] USER1 WITHDRAWs 29.30 from DAI proceeds
# [2023-04-06 23:14:15] USER1 WITHDRAWs 23.58 SYS
# [2023-04-06 23:14:15] USER1 DEPOSITs 23.58 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-08 11:13:07] USER2 DEPOSITs 5471.35 SYS
# [2023-04-08 11:13:07] USER2 SWAPs 2735.67 SYS for DAI
# [2023-04-08 11:13:07] USER2 WITHDRAWs 2735.67 from DAI proceeds
# [2023-04-08 11:13:07] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-08 11:13:07] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-08 12:13:41] USER1 DEPOSITs 49.18 SYS
# [2023-04-08 12:13:41] USER1 SWAPs 25.07 SYS for DAI
# [2023-04-08 12:13:41] USER1 WITHDRAWs 25.07 from DAI proceeds
# [2023-04-08 12:13:41] USER1 WITHDRAWs 22.15 SYS
# [2023-04-08 12:13:41] USER1 DEPOSITs 22.15 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-08 15:30:13] USER2 DEPOSITs 5470.93 SYS
# [2023-04-08 15:30:13] USER2 SWAPs 2735.47 SYS for DAI
# [2023-04-08 15:30:13] USER2 WITHDRAWs 2735.47 from DAI proceeds
# [2023-04-08 15:30:13] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-08 15:30:13] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-09 16:06:41] USER1 DEPOSITs 50.96 SYS
# [2023-04-09 16:06:41] USER1 SWAPs 27.59 SYS for DAI
# [2023-04-09 16:06:41] USER1 WITHDRAWs 27.59 from DAI proceeds
# [2023-04-09 16:06:41] USER1 WITHDRAWs 13.84 SYS
# [2023-04-09 16:06:41] USER1 DEPOSITs 13.84 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-09 21:46:39] USER2 DEPOSITs 5470.51 SYS
# [2023-04-09 21:46:39] USER2 SWAPs 2735.26 SYS for DAI
# [2023-04-09 21:46:39] USER2 WITHDRAWs 2735.26 from DAI proceeds
# [2023-04-09 21:46:39] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-09 21:46:39] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-10 20:00:25] USER2 DEPOSITs 5470.10 SYS
# [2023-04-10 20:00:25] USER2 SWAPs 2735.05 SYS for DAI
# [2023-04-10 20:00:25] USER2 WITHDRAWs 2735.05 from DAI proceeds
# [2023-04-10 20:00:25] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-10 20:00:25] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-10 23:11:55] USER1 DEPOSITs 48.00 SYS
# [2023-04-10 23:11:55] USER1 SWAPs 15.15 SYS for DAI
# [2023-04-10 23:11:55] USER1 WITHDRAWs 15.15 from DAI proceeds
# [2023-04-10 23:11:55] USER1 WITHDRAWs 22.19 SYS
# [2023-04-10 23:11:55] USER1 DEPOSITs 22.19 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-11 00:44:41] USER2 DEPOSITs 5469.68 SYS
# [2023-04-11 00:44:41] USER2 SWAPs 2734.84 SYS for DAI
# [2023-04-11 00:44:41] USER2 WITHDRAWs 2734.84 from DAI proceeds
# [2023-04-11 00:44:41] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-11 00:44:41] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-13 03:04:26] USER2 DEPOSITs 5469.27 SYS
# [2023-04-13 03:04:26] USER2 SWAPs 2734.63 SYS for DAI
# [2023-04-13 03:04:26] USER2 WITHDRAWs 2734.63 from DAI proceeds
# [2023-04-13 03:04:26] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-13 03:04:26] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-13 14:06:08] USER2 DEPOSITs 5468.85 SYS
# [2023-04-13 14:06:08] USER2 SWAPs 2734.43 SYS for DAI
# [2023-04-13 14:06:08] USER2 WITHDRAWs 2734.43 from DAI proceeds
# [2023-04-13 14:06:08] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-13 14:06:08] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-14 06:58:02] USER1 DEPOSITs 50.78 SYS
# [2023-04-14 06:58:02] USER1 SWAPs 27.88 SYS for DAI
# [2023-04-14 06:58:02] USER1 WITHDRAWs 27.88 from DAI proceeds
# [2023-04-14 06:58:02] USER1 WITHDRAWs 26.77 SYS
# [2023-04-14 06:58:02] USER1 DEPOSITs 26.77 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-14 16:49:13] USER1 DEPOSITs 53.98 SYS
# [2023-04-14 16:49:13] USER1 SWAPs 24.11 SYS for DAI
# [2023-04-14 16:49:13] USER1 WITHDRAWs 24.11 from DAI proceeds
# [2023-04-14 16:49:13] USER1 WITHDRAWs 33.49 SYS
# [2023-04-14 16:49:13] USER1 DEPOSITs 33.49 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-15 09:47:35] USER2 DEPOSITs 5468.44 SYS
# [2023-04-15 09:47:35] USER2 SWAPs 2734.22 SYS for DAI
# [2023-04-15 09:47:35] USER2 WITHDRAWs 2734.22 from DAI proceeds
# [2023-04-15 09:47:35] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-15 09:47:35] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-17 03:47:40] USER1 DEPOSITs 55.44 SYS
# [2023-04-17 03:47:40] USER1 SWAPs 22.58 SYS for DAI
# [2023-04-17 03:47:40] USER1 WITHDRAWs 22.58 from DAI proceeds
# [2023-04-17 03:47:40] USER1 WITHDRAWs 23.85 SYS
# [2023-04-17 03:47:40] USER1 DEPOSITs 23.85 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-17 12:04:24] USER1 DEPOSITs 47.68 SYS
# [2023-04-17 12:04:24] USER1 SWAPs 29.43 SYS for DAI
# [2023-04-17 12:04:24] USER1 WITHDRAWs 29.43 from DAI proceeds
# [2023-04-17 12:04:24] USER1 WITHDRAWs 22.73 SYS
# [2023-04-17 12:04:24] USER1 DEPOSITs 22.73 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-17 17:28:33] USER1 DEPOSITs 50.04 SYS
# [2023-04-17 17:28:33] USER1 SWAPs 29.58 SYS for DAI
# [2023-04-17 17:28:33] USER1 WITHDRAWs 29.58 from DAI proceeds
# [2023-04-17 17:28:33] USER1 WITHDRAWs 21.27 SYS
# [2023-04-17 17:28:33] USER1 DEPOSITs 21.27 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-18 05:23:35] USER2 DEPOSITs 5468.02 SYS
# [2023-04-18 05:23:35] USER2 SWAPs 2734.01 SYS for DAI
# [2023-04-18 05:23:35] USER2 WITHDRAWs 2734.01 from DAI proceeds
# [2023-04-18 05:23:35] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-18 05:23:35] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-19 03:29:15] USER2 DEPOSITs 5467.61 SYS
# [2023-04-19 03:29:15] USER2 SWAPs 2733.80 SYS for DAI
# [2023-04-19 03:29:15] USER2 WITHDRAWs 2733.80 from DAI proceeds
# [2023-04-19 03:29:15] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-19 03:29:15] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-19 09:16:04] USER2 DEPOSITs 5467.19 SYS
# [2023-04-19 09:16:04] USER2 SWAPs 2733.60 SYS for DAI
# [2023-04-19 09:16:04] USER2 WITHDRAWs 2733.60 from DAI proceeds
# [2023-04-19 09:16:04] USER2 WITHDRAWs 2500.00 SYS
# [2023-04-19 09:16:04] USER1 DEPOSITs 2500.00 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-20 04:45:03] USER1 DEPOSITs 44.54 SYS
# [2023-04-20 04:45:03] USER1 SWAPs 16.78 SYS for DAI
# [2023-04-20 04:45:03] USER1 WITHDRAWs 16.78 from DAI proceeds
# [2023-04-20 04:45:03] USER1 WITHDRAWs 33.83 SYS
# [2023-04-20 04:45:03] USER1 DEPOSITs 33.83 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-22 14:55:28] USER1 DEPOSITs 47.09 SYS
# [2023-04-22 14:55:28] USER1 SWAPs 26.75 SYS for DAI
# [2023-04-22 14:55:28] USER1 WITHDRAWs 26.75 from DAI proceeds
# [2023-04-22 14:55:28] USER1 WITHDRAWs 31.18 SYS
# [2023-04-22 14:55:28] USER1 DEPOSITs 31.18 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-23 22:07:30] USER1 DEPOSITs 48.68 SYS
# [2023-04-23 22:07:30] USER1 SWAPs 21.97 SYS for DAI
# [2023-04-23 22:07:30] USER1 WITHDRAWs 21.97 from DAI proceeds
# [2023-04-23 22:07:30] USER1 WITHDRAWs 32.89 SYS
# [2023-04-23 22:07:30] USER1 DEPOSITs 32.89 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-24 03:50:43] USER1 DEPOSITs 41.05 SYS
# [2023-04-24 03:50:43] USER1 SWAPs 28.64 SYS for DAI
# [2023-04-24 03:50:43] USER1 WITHDRAWs 28.64 from DAI proceeds
# [2023-04-24 03:50:43] USER1 WITHDRAWs 33.72 SYS
# [2023-04-24 03:50:43] USER1 DEPOSITs 33.72 SYS_DAI_LP from SYS and DAI proceeds
# [2023-04-24 23:23:15] USER1 DEPOSITs 47.78 SYS
# [2023-04-24 23:23:15] USER1 SWAPs 27.99 SYS for DAI
# [2023-04-24 23:23:15] USER1 WITHDRAWs 27.99 from DAI proceeds
# [2023-04-24 23:23:15] USER1 WITHDRAWs 21.72 SYS
# [2023-04-24 23:23:15] USER1 DEPOSITs 21.72 SYS_DAI_LP from SYS and DAI proceeds

# %% [markdown]
# ### Analyze

# %%
tSYS = SYS.get_token()
tDAI = DAI.get_token()
tSYS_DAI = SYS_DAI.get_token()

SYS_addr1 = SYS.get_address(SYS_mint1.get_id())
DAI_addr1 = DAI.get_address(DAI_mint1.get_id())
SYS_DAI_addr1 = SYS_DAI.get_address(SYS_DAI_LP_mint1.get_id())

# %%
SYS_states1 = tSYS.get_state_series(SYS_addr1)
principle = SYS_states1.get_principle() 
balance = SYS_states1.get_balance() 
tSamp = SYS_states1.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_ax.set_title("USER1: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states1 = tDAI.get_state_series(DAI_addr1)
principle = DAI_states1.get_principle() 
balance = DAI_states1.get_balance() 
tSamp = DAI_states1.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER1: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states1 = tSYS_DAI.get_state_series(SYS_DAI_addr1)
principle = SYS_DAI_states1.get_principle() 
balance = SYS_DAI_states1.get_balance() 
tSamp = SYS_DAI_states1.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
SYS_addr2 = SYS.get_address(SYS_mint2.get_id())
DAI_addr2 = DAI.get_address(DAI_mint2.get_id())
SYS_DAI_addr2 = SYS_DAI.get_address(SYS_DAI_LP_mint2.get_id())

# %%
SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp()

# %%
# Analyze Token balances

SYS_states2 = tSYS.get_state_series(SYS_addr2)
principle = SYS_states2.get_principle() 
balance = SYS_states2.get_balance() 
tSamp = SYS_states2.get_tstamp()  

fig, (SYS_ax, DAI_ax, SYS_DAI_ax) = plt.subplots(nrows=3, sharex=True, sharey=False, figsize=(18, 15))

SYS_ax.plot(tSamp, balance, label='balance') 
SYS_ax.plot(tSamp, principle, label='principle') 
SYS_ax.set_title("USER2: SYS Balance (rebasing token)", fontsize=20)
SYS_ax.set_ylabel("Token balance (SYS)", fontsize=16)
SYS_ax.set_xlabel('Time', fontsize=16)
SYS_ax.legend()

DAI_states2 = tDAI.get_state_series(DAI_addr2)
principle = DAI_states2.get_principle() 
balance = DAI_states2.get_balance() 
tSamp = DAI_states2.get_tstamp() 

DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
DAI_ax.set_title("USER2: DAI Balance (rebasing token)", fontsize=20)
DAI_ax.set_ylabel("Token balance (SYS)", fontsize=16)
DAI_ax.set_xlabel('Time', fontsize=16)
DAI_ax.legend()

SYS_DAI_states2 = tSYS_DAI.get_state_series(SYS_DAI_addr2)
principle = SYS_DAI_states2.get_principle() 
balance = SYS_DAI_states2.get_balance() 
tSamp = SYS_DAI_states2.get_tstamp() 

SYS_DAI_ax.plot(tSamp[1:], balance[1:], label='balance') 
SYS_DAI_ax.plot(tSamp[1:], principle[1:], label='principle') 
SYS_DAI_ax.set_title("USER1: SYS_DAI_LP Balance (rebasing token)", fontsize=20)
SYS_DAI_ax.set_ylabel("Token balance", fontsize=16)
SYS_DAI_ax.set_xlabel('Time', fontsize=16)
SYS_DAI_ax.legend()

# %%
tSamp = SYS_DAI_LP.get_lp_events().get_dates()
utSamp = SYS_DAI_LP.get_lp_events().get_unix_time_stamps()
prices = SYS_DAI_LP.get_lp_events().get_prices()
liquidities = SYS_DAI_LP.get_lp_events().get_liquidity_values()
balances = SYS_DAI_LP.get_lp_events().gen_yield_balances(apy)

fig, (liq_ax) = plt.subplots(nrows=1, sharex=True, sharey=False, figsize=(18, 15))

liq_ax.plot(tSamp, liquidities, label='liquidities') 
liq_ax.plot(tSamp, balances, label='liquidities') 
liq_ax.set_title("Total SYS_DAI_LP Balance (rebasing token)", fontsize=20)
liq_ax.set_ylabel("Token balance", fontsize=16)
liq_ax.set_xlabel('Time', fontsize=16)
liq_ax.legend()
